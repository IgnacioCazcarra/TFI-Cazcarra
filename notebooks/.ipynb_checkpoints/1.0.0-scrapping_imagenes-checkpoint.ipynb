# %%
! pip install GoogleImageScraper

# %%
# !pip install Pillow

# %%
import GoogleImageScraper

GOOGLE_SEARCH = ["ER Diagrams MySQL","mysql workbench diagramas entidad relacion"]
LIMIT = 99
ARGS = {"download_format":"png", "directory":"../data/imagenes_diagramas", "timeout":"30", "verbose":True}

# %%
for search in GOOGLE_SEARCH:
    images = GoogleImageScraper.download(query=search, limit=LIMIT, arguments=ARGS)

# %%
GOOGLE_SEARCH2 = "mysql workbench diagramas entidad relacion"
LIMIT = 5
images = GoogleImageScraper.download(query=GOOGLE_SEARCH2, limit=LIMIT, arguments=ARGS)
# Out:
# Extracting image urls from "https://www.google.com/search?tbm=isch&q=mysql%20workbench%20diagramas%20entidad%20relacion"
# Downloaded "mysqlworkbenchdiagramasentidadrelacion-2.jpg" to "C:\Users\Diego\Desktop\TFI-Cazcarra\notebooks\../data/imagenes_diagramas\mysqlworkbenchdiagramasentidadrelacion-2.jpg"
# ---------------------------------------------------------------------------
# RemoteDisconnected                        Traceback (most recent call last)
# File ~\anaconda3\envs\tfi\lib\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
# ...
