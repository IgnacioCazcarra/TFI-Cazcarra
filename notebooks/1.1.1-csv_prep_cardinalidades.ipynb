# %%
from glob import glob
import random
import os
import xml.etree.ElementTree as ET
import shutil
import numpy as np
import pandas as pd

from PIL import Image

# %%
import sys
sys.path.append("../")

from src.constants import *

# %%
BASE_DIR_IMG = f"{PATH}/data/tiles/image_slices/"
BASE_DIR_XML = f"{PATH}/data/tiles/xml_slices/"

CSV = f"{PATH}/data/tiles/data_cardinalidades_sliced.csv"

# %%
FILES = glob(BASE_DIR_XML+"*.xml") + glob(BASE_DIR_IMG+"*.png")
IMAGES = glob(os.path.join(BASE_DIR_IMG,"*.png"))

# %%
CLASSES = ['muchos_opcional','muchos_obligatorio','uno_opcional','uno_obligatorio']

# %%
def generate_train_test(dataset):    
    for (dtype, image_paths, output_csv) in dataset:
        print ("[INFO] creating '{}' set...".format(dtype))
        print ("[INFO] {} total images in '{}' set".format(len(image_paths), dtype))

        csv = open(output_csv, "w")
        
        header_row = ["image_path","xmin", "ymin", "xmax", "ymax", "label"]
        csv.write("{}\n".format(",".join(header_row)))
        
        for image_path in image_paths:
            fname = image_path.split("/")[-1]
            fname = fname[:fname.rfind(".")]+".xml"
            annot_path = BASE_DIR_XML + fname
            tree = ET.parse(annot_path)
            root = tree.getroot()
            size = root.find("size")
#             h = int(size.find("height").text)
#             w = int(size.find("width").text)

            w,h = Image.open(image_path).size
            print(image_path, w, h)
            
            for label in CLASSES:
                for o in tree.iter("object"):
                    if o.find("name").text==label:
                        box = o.find("bndbox")
                        xmin = int(box.find("xmin").text)
                        ymin = int(box.find("ymin").text)
                        xmax = int(box.find("xmax").text)
                        ymax = int(box.find("ymax").text)
                        # truncate any bounding box coordinates that fall outside
                        # the boundaries of the image
                        xmin = max(0, xmin)
                        ymin = max(0, ymin)
                        xmax = min(w, xmax)
                        ymax = min(h, ymax)

                        # ignore the bounding boxes where the minimum values are larger
                        # than the maximum values and vice-versa due to annotation errors
                        if xmin >= xmax or ymin >= ymax:
                            print("a")
                            continue
                        elif xmax <= xmin or ymax <= ymin:
                            print("b")
                            continue

                        row = [os.path.abspath(image_path),str(xmin), str(ymin), str(xmax), str(ymax), str(label)]
                        csv.write("{}\n".format(",".join(row)))
        csv.close()

# %%
def split_wrapper():    
    dataset = [("csv", IMAGES, CSV)]
    #Create and write train and test csv
    generate_train_test(dataset)

# %%
def get_val_count(df):
    return df[df.columns[-1]].value_counts()

split_wrapper()

csv = pd.read_csv(CSV)
csv.head()
# Out:
# [INFO] creating 'csv' set...
# [INFO] 240 total images in 'csv' set
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000005.png 516 637
# muchos_obligatorio
# 279 64 297 83
# 279 64 297 83
# muchos_obligatorio
# 210 133 228 150
# 210 133 228 150
# uno_opcional
# 546 64 563 84
# 546 64 563 84
# uno_opcional
# 283 317 302 337
# 283 317 302 337
# uno_obligatorio
# 384 65 400 83
# 384 65 400 83
# uno_obligatorio
# 209 252 230 270
# 209 252 230 270
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000094.png 529 504
# muchos_obligatorio
# 442 430 463 446
# 442 430 463 446
# muchos_obligatorio
# 435 166 453 182
# 435 166 453 182
# uno_obligatorio
# 368 49 384 63
# 368 49 384 63
# uno_obligatorio
# 415 47 433 63
# 415 47 433 63
# uno_obligatorio
# 399 174 416 190
# 399 174 416 190
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000212.png 312 242
# muchos_opcional
# 10 178 33 199
# 10 178 33 199
# uno_opcional
# 11 257 33 277
# 11 257 33 277
# uno_opcional
# 227 180 173 202
# 227 180 173 202
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000089.png 585 665
# muchos_obligatorio
# 75 337 89 353
# 75 337 89 353
# muchos_obligatorio
# 75 371 89 384
# 75 371 89 384
# muchos_obligatorio
# 75 404 88 418
# 75 404 88 418
# muchos_obligatorio
# 192 347 206 361
# 192 347 206 361
# muchos_obligatorio
# 193 387 208 402
# 193 387 208 402
# muchos_obligatorio
# 193 428 209 444
# 193 428 209 444
# muchos_obligatorio
# 275 457 292 472
# 275 457 292 472
# muchos_obligatorio
# 299 457 314 471
# 299 457 314 471
# muchos_obligatorio
# 322 457 336 471
# 322 457 336 471
# muchos_obligatorio
# 345 457 359 471
# 345 457 359 471
# muchos_obligatorio
# 373 524 386 540
# 373 524 386 540
# muchos_obligatorio
# 409 436 423 450
# 409 436 423 450
# muchos_obligatorio
# 408 370 423 384
# 408 370 423 384
# muchos_obligatorio
# 570 326 582 341
# 570 326 582 341
# muchos_obligatorio
# 556 371 569 385
# 556 371 569 385
# muchos_obligatorio
# 482 298 498 311
# 482 298 498 311
# muchos_obligatorio
# 381 212 393 226
# 381 212 393 226
# muchos_obligatorio
# 556 435 570 452
# 556 435 570 452
# muchos_obligatorio
# 620 108 635 122
# 620 108 635 122
# uno_obligatorio
# 76 437 89 451
# 76 437 89 451
# uno_obligatorio
# 150 253 164 266
# 150 253 164 266
# uno_obligatorio
# 249 339 262 351
# 249 339 262 351
# uno_obligatorio
# 248 372 262 386
# 248 372 262 386
# uno_obligatorio
# 316 413 329 425
# 316 413 329 425
# uno_obligatorio
# 571 398 582 413
# 571 398 582 413
# uno_obligatorio
# 571 378 582 389
# 571 378 582 389
# uno_obligatorio
# 570 351 582 364
# 570 351 582 364
# uno_obligatorio
# 386 329 400 345
# 386 329 400 345
# uno_obligatorio
# 386 355 399 369
# 386 355 399 369
# uno_obligatorio
# 386 381 398 394
# 386 381 398 394
# uno_obligatorio
# 534 196 545 208
# 534 196 545 208
# uno_obligatorio
# 472 254 484 266
# 472 254 484 266
# uno_obligatorio
# 410 195 423 208
# 410 195 423 208
# uno_obligatorio
# 317 299 330 311
# 317 299 330 311
# uno_obligatorio
# 612 300 625 310
# 612 300 625 310
# uno_obligatorio
# 650 300 661 311
# 650 300 661 311
# uno_obligatorio
# 443 92 456 104
# 443 92 456 104
# uno_obligatorio
# 470 92 483 105
# 470 92 483 105
# uno_obligatorio
# 498 93 510 105
# 498 93 510 105
# uno_obligatorio
# 530 34 543 48
# 530 34 543 48
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000072.png 722 438
# muchos_obligatorio
# 0 442 12 460
# 0 442 12 460
# muchos_obligatorio
# 60 307 80 329
# 60 307 80 329
# uno_obligatorio
# 50 579 68 595
# 50 579 68 595
# uno_obligatorio
# 252 463 268 481
# 252 463 268 481
# uno_obligatorio
# 59 183 77 201
# 59 183 77 201
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000185.png 278 337
# muchos_opcional
# 154 30 178 52
# 154 30 178 52
# muchos_opcional
# 83 249 107 269
# 83 249 107 269
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000202.png 463 519
# muchos_opcional
# 109 23 139 50
# 109 23 139 50
# muchos_opcional
# 177 21 205 48
# 177 21 205 48
# muchos_opcional
# 360 211 388 238
# 360 211 388 238
# uno_opcional
# 109 225 140 252
# 109 225 140 252
# uno_opcional
# 204 294 230 324
# 204 294 230 324
# uno_opcional
# 203 351 230 380
# 203 351 230 380
# uno_opcional
# 358 164 388 194
# 358 164 388 194
# uno_opcional
# 451 104 480 130
# 451 104 480 130
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000087.png 585 665
# muchos_obligatorio
# 95 577 107 418
# 95 577 107 418
# a
# muchos_obligatorio
# 7 549 23 562
# 7 549 23 562
# muchos_obligatorio
# 415 534 430 548
# 415 534 430 548
# muchos_obligatorio
# 414 505 428 519
# 414 505 428 519
# muchos_obligatorio
# 414 477 429 492
# 414 477 429 492
# muchos_obligatorio
# 414 449 429 464
# 414 449 429 464
# muchos_obligatorio
# 415 422 429 436
# 415 422 429 436
# muchos_obligatorio
# 198 295 211 308
# 198 295 211 308
# muchos_obligatorio
# 145 359 160 373
# 145 359 160 373
# muchos_obligatorio
# 16 230 29 241
# 16 230 29 241
# muchos_obligatorio
# 58 149 71 165
# 58 149 71 165
# uno_obligatorio
# 59 447 70 459
# 59 447 70 459
# uno_obligatorio
# 0 505 9 517
# 0 505 9 517
# uno_obligatorio
# 393 415 406 428
# 393 415 406 428
# uno_obligatorio
# 254 285 268 299
# 254 285 268 299
# uno_obligatorio
# 255 337 269 351
# 255 337 269 351
# uno_obligatorio
# 255 388 268 402
# 255 388 268 402
# uno_obligatorio
# 255 440 268 454
# 255 440 268 454
# uno_obligatorio
# 255 493 267 505
# 255 493 267 505
# uno_obligatorio
# 256 544 268 557
# 256 544 268 557
# uno_obligatorio
# 137 551 150 561
# 137 551 150 561
# uno_obligatorio
# 175 551 186 562
# 175 551 186 562
# uno_obligatorio
# 0 343 8 356
# 0 343 8 356
# uno_obligatorio
# 23 344 35 356
# 23 344 35 356
# uno_obligatorio
# 55 285 68 299
# 55 285 68 299
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000235.png 541 396
# muchos_obligatorio
# 287 171 313 197
# 287 171 313 197
# muchos_obligatorio
# 176 505 206 532
# 176 505 206 532
# muchos_obligatorio
# 341 505 368 533
# 341 505 368 533
# uno_obligatorio
# 205 166 230 193
# 205 166 230 193
# uno_obligatorio
# 179 359 204 382
# 179 359 204 382
# uno_obligatorio
# 341 357 368 382
# 341 357 368 382
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000192.png 362 362
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000053.png 371 334
# uno_opcional
# 249 138 265 154
# 249 138 265 154
# uno_opcional
# 273 223 289 238
# 273 223 289 238
# uno_obligatorio
# 213 304 230 319
# 213 304 230 319
# uno_obligatorio
# 93 239 108 256
# 93 239 108 256
# uno_obligatorio
# 304 224 318 239
# 304 224 318 239
# uno_obligatorio
# 303 32 319 48
# 303 32 319 48
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000033.png 345 240
# muchos_opcional
# 147 207 168 227
# 147 207 168 227
# uno_opcional
# 66 91 85 108
# 66 91 85 108
# uno_obligatorio
# 147 138 166 154
# 147 138 166 154
# uno_obligatorio
# 70 52 87 69
# 70 52 87 69
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000061.png 662 596
# uno_obligatorio
# 530 433 548 450
# 530 433 548 450
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000084.png 590 421
# muchos_obligatorio
# 284 187 309 210
# 284 187 309 210
# muchos_obligatorio
# 0 202 16 225
# 0 202 16 225
# uno_obligatorio
# 285 390 308 412
# 285 390 308 412
# uno_obligatorio
# 221 389 244 411
# 221 389 244 411
# uno_obligatorio
# 144 459 167 483
# 144 459 167 483
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000165.png 285 487
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000152.png 252 302
# muchos_obligatorio
# 122 149 132 158
# 122 149 132 158
# muchos_obligatorio
# 154 149 163 157
# 154 149 163 157
# muchos_obligatorio
# 114 229 123 238
# 114 229 123 238
# uno_obligatorio
# 273 241 282 249
# 273 241 282 249
# uno_obligatorio
# 278 97 286 106
# 278 97 286 106
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000044.png 464 595
# muchos_obligatorio
# 457 185 480 204
# 457 185 480 204
# muchos_obligatorio
# 460 232 480 251
# 460 232 480 251
# muchos_obligatorio
# 458 281 479 300
# 458 281 479 300
# uno_obligatorio
# 235 194 255 216
# 235 194 255 216
# uno_obligatorio
# 245 414 264 435
# 245 414 264 435
# uno_obligatorio
# 245 461 266 332
# 245 461 266 332
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000004.png 516 637
# muchos_obligatorio
# 552 64 570 83
# 552 64 570 83
# muchos_obligatorio
# 483 133 501 150
# 483 133 501 150
# uno_opcional
# 556 317 575 337
# 556 317 575 337
# uno_obligatorio
# 482 252 503 270
# 482 252 503 270
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000076.png 347 298
# muchos_obligatorio
# 164 68 177 82
# 164 68 177 82
# muchos_obligatorio
# 282 69 296 84
# 282 69 296 84
# uno_opcional
# 136 68 151 84
# 136 68 151 84
# uno_opcional
# 66 11 82 26
# 66 11 82 26
# uno_opcional
# 66 125 82 141
# 66 125 82 141
# uno_opcional
# 144 261 159 278
# 144 261 159 278
# uno_opcional
# 278 261 293 277
# 278 261 293 277
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000142.png 624 553
# muchos_obligatorio
# 524 382 543 398
# 524 382 543 398
# uno_obligatorio
# 429 25 447 45
# 429 25 447 45
# uno_obligatorio
# 429 182 446 200
# 429 182 446 200
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000186.png 278 337
# muchos_opcional
# 237 16 259 37
# 237 16 259 37
# muchos_obligatorio
# 161 15 182 36
# 161 15 182 36
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000180.png 574 467
# uno_opcional
# 248 38 280 72
# 248 38 280 72
# uno_opcional
# 246 102 279 137
# 246 102 279 137
# uno_obligatorio
# 0 413 12 444
# 0 413 12 444
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000211.png 312 242
# muchos_opcional
# 114 178 137 199
# 114 178 137 199
# uno_opcional
# 115 257 137 277
# 115 257 137 277
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000216.png 312 242
# uno_opcional
# 54 46 76 68
# 54 46 76 68
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000097.png 851 863
# muchos_obligatorio
# 352 361 375 382
# 352 361 375 382
# muchos_obligatorio
# 492 296 511 317
# 492 296 511 317
# muchos_obligatorio
# 593 519 615 539
# 593 519 615 539
# muchos_obligatorio
# 826 363 848 382
# 826 363 848 382
# muchos_obligatorio
# 634 816 654 837
# 634 816 654 837
# uno_obligatorio
# 239 113 257 134
# 239 113 257 134
# uno_obligatorio
# 237 187 258 208
# 237 187 258 208
# uno_obligatorio
# 279 177 301 195
# 279 177 301 195
# uno_obligatorio
# 281 125 300 143
# 281 125 300 143
# uno_obligatorio
# 355 236 375 255
# 355 236 375 255
# uno_obligatorio
# 419 237 437 255
# 419 237 437 255
# uno_obligatorio
# 490 112 509 132
# 490 112 509 132
# uno_obligatorio
# 490 151 509 170
# 490 151 509 170
# uno_obligatorio
# 489 189 507 207
# 489 189 507 207
# uno_obligatorio
# 725 109 743 125
# 725 109 743 125
# uno_obligatorio
# 725 157 744 177
# 725 157 744 177
# uno_obligatorio
# 829 217 848 235
# 829 217 848 235
# uno_obligatorio
# 596 400 613 418
# 596 400 613 418
# uno_obligatorio
# 706 415 723 433
# 706 415 723 433
# uno_obligatorio
# 705 457 724 474
# 705 457 724 474
# uno_obligatorio
# 460 414 478 435
# 460 414 478 435
# uno_obligatorio
# 459 455 478 475
# 459 455 478 475
# uno_obligatorio
# 461 498 479 517
# 461 498 479 517
# uno_obligatorio
# 537 522 554 537
# 537 522 554 537
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000055.png 442 442
# muchos_obligatorio
# 289 123 316 152
# 289 123 316 152
# uno_obligatorio
# 207 288 230 313
# 207 288 230 313
# uno_obligatorio
# 207 211 229 232
# 207 211 229 232
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000034.png 345 240
# muchos_opcional
# 154 50 174 68
# 154 50 174 68
# muchos_opcional
# 75 155 95 174
# 75 155 95 174
# uno_opcional
# 155 3 173 19
# 155 3 173 19
# uno_obligatorio
# 77 111 94 127
# 77 111 94 127
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000022.png 740 590
# muchos_obligatorio
# 130 32 151 51
# 130 32 151 51
# muchos_obligatorio
# 201 160 219 178
# 201 160 219 178
# muchos_obligatorio
# 287 243 305 262
# 287 243 305 262
# muchos_obligatorio
# 100 456 119 472
# 100 456 119 472
# muchos_obligatorio
# 179 522 198 541
# 179 522 198 541
# muchos_obligatorio
# 374 322 392 339
# 374 322 392 339
# muchos_obligatorio
# 529 504 548 522
# 529 504 548 522
# muchos_obligatorio
# 527 79 548 98
# 527 79 548 98
# uno_obligatorio
# 71 35 89 51
# 71 35 89 51
# uno_obligatorio
# 289 28 307 43
# 289 28 307 43
# uno_obligatorio
# 200 280 216 297
# 200 280 216 297
# uno_obligatorio
# 101 409 119 424
# 101 409 119 424
# uno_obligatorio
# 212 522 230 539
# 212 522 230 539
# uno_obligatorio
# 438 424 455 443
# 438 424 455 443
# uno_obligatorio
# 463 242 480 261
# 463 242 480 261
# uno_obligatorio
# 528 345 551 364
# 528 345 551 364
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000104.png 959 648
# muchos_obligatorio
# 334 144 352 164
# 334 144 352 164
# muchos_obligatorio
# 334 238 352 257
# 334 238 352 257
# muchos_obligatorio
# 422 682 444 701
# 422 682 444 701
# muchos_obligatorio
# 154 892 174 911
# 154 892 174 911
# muchos_obligatorio
# 45 673 63 690
# 45 673 63 690
# muchos_obligatorio
# 0 232 11 250
# 0 232 11 250
# uno_obligatorio
# 474 236 493 255
# 474 236 493 255
# uno_obligatorio
# 335 333 351 350
# 335 333 351 350
# uno_obligatorio
# 334 425 353 444
# 334 425 353 444
# uno_obligatorio
# 152 786 169 802
# 152 786 169 802
# uno_obligatorio
# 125 364 142 380
# 125 364 142 380
# uno_obligatorio
# 123 208 142 224
# 123 208 142 224
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000154.png 252 302
# muchos_obligatorio
# 252 41 262 50
# 252 41 262 50
# muchos_obligatorio
# 284 41 293 49
# 284 41 293 49
# muchos_obligatorio
# 244 121 253 130
# 244 121 253 130
# muchos_obligatorio
# 244 192 254 202
# 244 192 254 202
# uno_obligatorio
# 244 156 253 166
# 244 156 253 166
# uno_obligatorio
# 281 220 289 228
# 281 220 289 228
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000092.png 529 504
# muchos_obligatorio
# 409 479 427 497
# 409 479 427 497
# muchos_obligatorio
# 219 393 237 409
# 219 393 237 409
# muchos_obligatorio
# 295 462 314 478
# 295 462 314 478
# muchos_obligatorio
# 432 287 452 303
# 432 287 452 303
# uno_obligatorio
# 152 276 168 290
# 152 276 168 290
# uno_obligatorio
# 199 274 217 290
# 199 274 217 290
# uno_obligatorio
# 183 401 200 417
# 183 401 200 417
# uno_obligatorio
# 391 288 410 303
# 391 288 410 303
# uno_obligatorio
# 474 287 492 304
# 474 287 492 304
# uno_obligatorio
# 493 346 360 362
# 493 346 360 362
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000178.png 574 467
# muchos_obligatorio
# 399 22 429 50
# 399 22 429 50
# muchos_obligatorio
# 397 211 430 240
# 397 211 430 240
# muchos_obligatorio
# 206 413 236 444
# 206 413 236 444
# uno_obligatorio
# 397 0 428 7
# 397 0 428 7
# uno_obligatorio
# 277 411 310 444
# 277 411 310 444
# uno_obligatorio
# 397 287 429 317
# 397 287 429 317
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000122.png 404 310
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000082.png 590 421
# muchos_obligatorio
# 235 459 259 484
# 235 459 259 484
# muchos_obligatorio
# 236 351 261 376
# 236 351 261 376
# muchos_obligatorio
# 250 21 273 44
# 250 21 273 44
# uno_obligatorio
# 413 204 301 224
# 413 204 301 224
# a
# uno_obligatorio
# 346 84 366 105
# 346 84 366 105
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000179.png 574 467
# muchos_obligatorio
# 198 22 228 50
# 198 22 228 50
# muchos_obligatorio
# 196 211 229 240
# 196 211 229 240
# muchos_obligatorio
# 5 413 35 444
# 5 413 35 444
# uno_obligatorio
# 196 0 227 7
# 196 0 227 7
# uno_obligatorio
# 317 413 346 444
# 317 413 346 444
# uno_obligatorio
# 76 411 109 444
# 76 411 109 444
# uno_obligatorio
# 196 287 228 317
# 196 287 228 317
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000077.png 347 298
# muchos_obligatorio
# 211 262 226 277
# 211 262 226 277
# muchos_obligatorio
# 264 0 280 7
# 264 0 280 7
# muchos_obligatorio
# 36 68 49 82
# 36 68 49 82
# muchos_obligatorio
# 154 69 168 84
# 154 69 168 84
# muchos_obligatorio
# 265 213 281 229
# 265 213 281 229
# uno_opcional
# 8 68 23 84
# 8 68 23 84
# uno_opcional
# 16 261 31 278
# 16 261 31 278
# uno_opcional
# 150 261 165 277
# 150 261 165 277
# uno_opcional
# 265 145 280 160
# 265 145 280 160
# uno_opcional
# 185 68 199 83
# 185 68 199 83
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000132.png 515 561
# uno_obligatorio
# 90 66 123 93
# 90 66 123 93
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000042.png 492 541
# muchos_obligatorio
# 252 243 273 263
# 252 243 273 263
# muchos_obligatorio
# 345 399 366 418
# 345 399 366 418
# uno_obligatorio
# 18 119 39 137
# 18 119 39 137
# uno_obligatorio
# 122 320 141 340
# 122 320 141 340
# uno_obligatorio
# 306 399 324 418
# 306 399 324 418
# uno_obligatorio
# 387 398 407 416
# 387 398 407 416
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000199.png 463 519
# muchos_opcional
# 412 106 440 134
# 412 106 440 134
# muchos_opcional
# 109 222 139 249
# 109 222 139 249
# muchos_opcional
# 177 220 205 247
# 177 220 205 247
# muchos_opcional
# 360 410 388 437
# 360 410 388 437
# uno_opcional
# 259 106 287 135
# 259 106 287 135
# uno_opcional
# 109 424 140 451
# 109 424 140 451
# uno_opcional
# 358 363 388 393
# 358 363 388 393
# uno_opcional
# 451 303 480 329
# 451 303 480 329
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000102.png 851 863
# uno_obligatorio
# 339 153 356 169
# 339 153 356 169
# uno_obligatorio
# 339 131 357 146
# 339 131 357 146
# uno_obligatorio
# 414 153 430 169
# 414 153 430 169
# uno_obligatorio
# 412 130 429 147
# 412 130 429 147
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000197.png 599 547
# muchos_opcional
# 92 0 124 6
# 92 0 124 6
# muchos_opcional
# 2 81 34 111
# 2 81 34 111
# muchos_opcional
# 230 150 262 179
# 230 150 262 179
# muchos_opcional
# 434 448 465 482
# 434 448 465 482
# muchos_opcional
# 519 45 391 77
# 519 45 391 77
# a
# uno_opcional
# 191 0 217 3
# 191 0 217 3
# uno_opcional
# 282 60 314 89
# 282 60 314 89
# uno_opcional
# 380 0 409 5
# 380 0 409 5
# uno_opcional
# 341 267 371 297
# 341 267 371 297
# uno_opcional
# 342 367 374 402
# 342 367 374 402
# uno_opcional
# 521 366 391 394
# 521 366 391 394
# a
# uno_opcional
# 120 267 148 296
# 120 267 148 296
# uno_opcional
# 118 369 148 401
# 118 369 148 401
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000011.png 504 596
# muchos_obligatorio
# 190 416 207 432
# 190 416 207 432
# muchos_obligatorio
# 122 416 139 433
# 122 416 139 433
# muchos_obligatorio
# 248 281 263 300
# 248 281 263 300
# muchos_obligatorio
# 580 415 426 432
# 580 415 426 432
# a
# muchos_obligatorio
# 491 222 510 243
# 491 222 510 243
# muchos_obligatorio
# 343 173 361 189
# 343 173 361 189
# muchos_obligatorio
# 394 173 409 188
# 394 173 409 188
# muchos_obligatorio
# 399 211 416 227
# 399 211 416 227
# uno_obligatorio
# 492 119 508 135
# 492 119 508 135
# uno_obligatorio
# 346 210 364 226
# 346 210 364 226
# uno_obligatorio
# 166 37 183 53
# 166 37 183 53
# uno_obligatorio
# 157 415 174 432
# 157 415 174 432
# uno_obligatorio
# 541 416 557 431
# 541 416 557 431
# uno_obligatorio
# 585 338 426 353
# 585 338 426 353
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000191.png 362 362
# uno_opcional
# 112 207 135 229
# 112 207 135 229
# uno_obligatorio
# 52 27 72 46
# 52 27 72 46
# uno_obligatorio
# 11 27 32 46
# 11 27 32 46
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000221.png 506 397
# muchos_opcional
# 19 235 46 259
# 19 235 46 259
# muchos_opcional
# 218 276 244 302
# 218 276 244 302
# uno_opcional
# 55 0 79 13
# 55 0 79 13
# uno_opcional
# 379 45 284 67
# 379 45 284 67
# a
# uno_opcional
# 54 61 79 88
# 54 61 79 88
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000075.png 347 298
# muchos_obligatorio
# 133 217 147 231
# 133 217 147 231
# muchos_obligatorio
# 51 142 67 156
# 51 142 67 156
# uno_opcional
# 0 54 5 67
# 0 54 5 67
# uno_opcional
# 172 217 186 231
# 172 217 186 231
# uno_opcional
# 51 114 66 127
# 51 114 66 127
# uno_opcional
# 52 294 67 309
# 52 294 67 309
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000037.png 492 541
# muchos_obligatorio
# 522 367 387 387
# 522 367 387 387
# a
# uno_obligatorio
# 433 459 450 477
# 433 459 450 477
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000209.png 275 287
# muchos_opcional
# 59 0 80 12
# 59 0 80 12
# muchos_opcional
# 216 39 238 60
# 216 39 238 60
# uno_opcional
# 119 100 140 120
# 119 100 140 120
# uno_opcional
# 168 100 190 120
# 168 100 190 120
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000218.png 506 397
# muchos_opcional
# 19 453 46 477
# 19 453 46 477
# muchos_opcional
# 218 494 244 362
# 218 494 244 362
# a
# muchos_opcional
# 211 117 235 144
# 211 117 235 144
# muchos_opcional
# 291 178 317 204
# 291 178 317 204
# uno_opcional
# 55 205 79 231
# 55 205 79 231
# uno_opcional
# 379 263 284 285
# 379 263 284 285
# a
# uno_opcional
# 54 279 79 306
# 54 279 79 306
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000036.png 345 240
# muchos_opcional
# 147 58 168 78
# 147 58 168 78
# uno_obligatorio
# 147 0 166 5
# 147 0 166 5
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000144.png 624 553
# muchos_obligatorio
# 92 27 112 46
# 92 27 112 46
# muchos_obligatorio
# 179 197 196 212
# 179 197 196 212
# uno_obligatorio
# 60 382 76 399
# 60 382 76 399
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000233.png 186 271
# muchos_obligatorio
# 40 41 58 60
# 40 41 58 60
# muchos_obligatorio
# 256 0 194 5
# 256 0 194 5
# a
# uno_obligatorio
# 99 0 114 4
# 99 0 114 4
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000141.png 624 553
# muchos_obligatorio
# 92 295 112 314
# 92 295 112 314
# muchos_obligatorio
# 179 465 196 480
# 179 465 196 480
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000223.png 504 596
# muchos_obligatorio
# 495 391 514 407
# 495 391 514 407
# muchos_obligatorio
# 496 296 516 311
# 496 296 516 311
# uno_obligatorio
# 361 452 377 469
# 361 452 377 469
# uno_obligatorio
# 358 274 372 290
# 358 274 372 290
# uno_obligatorio
# 358 216 371 232
# 358 216 371 232
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000200.png 463 519
# muchos_opcional
# 314 219 341 244
# 314 219 341 244
# muchos_opcional
# 189 106 217 134
# 189 106 217 134
# muchos_opcional
# 137 410 165 437
# 137 410 165 437
# uno_opcional
# 36 106 64 135
# 36 106 64 135
# uno_opcional
# 135 363 165 393
# 135 363 165 393
# uno_opcional
# 319 363 347 391
# 319 363 347 391
# uno_opcional
# 321 408 348 437
# 321 408 348 437
# uno_opcional
# 228 303 257 329
# 228 303 257 329
# uno_opcional
# 438 106 467 135
# 438 106 467 135
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000041.png 492 541
# muchos_obligatorio
# 314 320 335 343
# 314 320 335 343
# muchos_obligatorio
# 289 155 309 175
# 289 155 309 175
# uno_obligatorio
# 200 247 217 265
# 200 247 217 265
# uno_obligatorio
# 405 119 426 137
# 405 119 426 137
# uno_obligatorio
# 509 320 528 340
# 509 320 528 340
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000009.png 504 596
# muchos_obligatorio
# 65 438 84 459
# 65 438 84 459
# uno_obligatorio
# 66 335 82 351
# 66 335 82 351
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000067.png 722 438
# muchos_obligatorio
# 83 392 106 412
# 83 392 106 412
# muchos_obligatorio
# 181 491 202 512
# 181 491 202 512
# uno_obligatorio
# 367 619 384 637
# 367 619 384 637
# uno_obligatorio
# 366 492 385 511
# 366 492 385 511
# uno_obligatorio
# 233 113 250 130
# 233 113 250 130
# uno_obligatorio
# 317 225 334 242
# 317 225 334 242
# uno_obligatorio
# 403 116 418 132
# 403 116 418 132
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000174.png 695 690
# muchos_obligatorio
# 154 623 174 642
# 154 623 174 642
# muchos_obligatorio
# 258 449 278 466
# 258 449 278 466
# muchos_obligatorio
# 42 236 58 254
# 42 236 58 254
# muchos_obligatorio
# 0 450 16 466
# 0 450 16 466
# uno_obligatorio
# 47 449 66 466
# 47 449 66 466
# uno_obligatorio
# 211 450 230 466
# 211 450 230 466
# uno_obligatorio
# 156 539 173 557
# 156 539 173 557
# uno_obligatorio
# 106 581 124 600
# 106 581 124 600
# uno_obligatorio
# 0 238 10 253
# 0 238 10 253
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000219.png 506 397
# muchos_opcional
# 7 178 33 204
# 7 178 33 204
# uno_opcional
# 95 263 121 285
# 95 263 121 285
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000129.png 515 561
# uno_obligatorio
# 90 287 123 314
# 90 287 123 314
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000100.png 851 863
# muchos_obligatorio
# 352 0 375 17
# 352 0 375 17
# muchos_obligatorio
# 593 154 615 174
# 593 154 615 174
# muchos_obligatorio
# 826 0 848 17
# 826 0 848 17
# muchos_obligatorio
# 634 451 654 472
# 634 451 654 472
# muchos_obligatorio
# 634 501 652 521
# 634 501 652 521
# muchos_obligatorio
# 775 597 797 616
# 775 597 797 616
# muchos_obligatorio
# 675 670 693 687
# 675 670 693 687
# uno_obligatorio
# 596 35 613 53
# 596 35 613 53
# uno_obligatorio
# 706 50 723 68
# 706 50 723 68
# uno_obligatorio
# 705 92 724 109
# 705 92 724 109
# uno_obligatorio
# 460 49 478 70
# 460 49 478 70
# uno_obligatorio
# 459 90 478 110
# 459 90 478 110
# uno_obligatorio
# 461 133 479 152
# 461 133 479 152
# uno_obligatorio
# 537 157 554 172
# 537 157 554 172
# uno_obligatorio
# 635 603 652 621
# 635 603 652 621
# uno_obligatorio
# 635 552 652 571
# 635 552 652 571
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000012.png 504 596
# muchos_obligatorio
# 154 415 171 432
# 154 415 171 432
# muchos_obligatorio
# 65 222 84 243
# 65 222 84 243
# uno_obligatorio
# 66 119 82 135
# 66 119 82 135
# uno_obligatorio
# 115 416 131 431
# 115 416 131 431
# uno_obligatorio
# 159 338 176 353
# 159 338 176 353
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000010.png 504 596
# muchos_obligatorio
# 446 416 463 432
# 446 416 463 432
# muchos_obligatorio
# 378 416 395 433
# 378 416 395 433
# muchos_obligatorio
# 504 281 519 300
# 504 281 519 300
# uno_obligatorio
# 422 37 439 53
# 422 37 439 53
# uno_obligatorio
# 413 415 430 432
# 413 415 430 432
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000135.png 1188 1019
# muchos_obligatorio
# 369 667 410 702
# 369 667 410 702
# muchos_obligatorio
# 234 865 270 902
# 234 865 270 902
# uno_obligatorio
# 371 445 405 476
# 371 445 405 476
# uno_obligatorio
# 145 866 176 899
# 145 866 176 899
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000190.png 362 362
# uno_opcional
# 268 207 291 229
# 268 207 291 229
# uno_opcional
# 134 193 155 214
# 134 193 155 214
# uno_obligatorio
# 208 27 228 46
# 208 27 228 46
# uno_obligatorio
# 167 27 188 46
# 167 27 188 46
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000057.png 442 442
# muchos_obligatorio
# 83 124 106 151
# 83 124 106 151
# uno_obligatorio
# 174 125 197 151
# 174 125 197 151
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000015.png 196 180
# muchos_obligatorio
# 95 185 115 140
# 95 185 115 140
# a
# uno_obligatorio
# 19 107 35 122
# 19 107 35 122
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000078.png 347 298
# muchos_obligatorio
# 0 262 13 277
# 0 262 13 277
# muchos_obligatorio
# 133 68 147 82
# 133 68 147 82
# muchos_obligatorio
# 51 0 67 7
# 51 0 67 7
# muchos_obligatorio
# 52 213 68 229
# 52 213 68 229
# uno_opcional
# 172 68 186 82
# 172 68 186 82
# uno_opcional
# 52 145 67 160
# 52 145 67 160
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000217.png 506 397
# muchos_opcional
# 190 453 217 477
# 190 453 217 477
# muchos_opcional
# 389 494 284 362
# 389 494 284 362
# a
# muchos_opcional
# 382 117 284 144
# 382 117 284 144
# a
# uno_opcional
# 226 205 250 231
# 226 205 250 231
# uno_opcional
# 225 279 250 306
# 225 279 250 306
# uno_opcional
# 120 369 148 392
# 120 369 148 392
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000040.png 492 541
# muchos_obligatorio
# 522 155 387 175
# 522 155 387 175
# a
# uno_obligatorio
# 433 247 450 265
# 433 247 450 265
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000155.png 252 302
# muchos_obligatorio
# 122 41 132 50
# 122 41 132 50
# muchos_obligatorio
# 154 41 163 49
# 154 41 163 49
# muchos_obligatorio
# 114 121 123 130
# 114 121 123 130
# muchos_obligatorio
# 114 192 124 202
# 114 192 124 202
# muchos_obligatorio
# 273 173 282 183
# 273 173 282 183
# uno_obligatorio
# 114 156 123 166
# 114 156 123 166
# uno_obligatorio
# 151 220 159 228
# 151 220 159 228
# uno_obligatorio
# 199 196 208 204
# 199 196 208 204
# uno_obligatorio
# 273 133 282 141
# 273 133 282 141
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000062.png 662 596
# muchos_obligatorio
# 558 144 578 161
# 558 144 578 161
# muchos_obligatorio
# 566 546 583 563
# 566 546 583 563
# muchos_obligatorio
# 380 347 400 366
# 380 347 400 366
# muchos_obligatorio
# 474 431 490 448
# 474 431 490 448
# uno_obligatorio
# 274 433 292 450
# 274 433 292 450
# uno_obligatorio
# 563 348 582 365
# 563 348 582 365
# uno_obligatorio
# 470 265 491 283
# 470 265 491 283
# uno_obligatorio
# 474 474 490 489
# 474 474 490 489
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000123.png 404 310
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000064.png 662 596
# uno_obligatorio
# 530 149 548 166
# 530 149 548 166
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000068.png 722 438
# muchos_obligatorio
# 273 357 296 376
# 273 357 296 376
# muchos_obligatorio
# 0 491 14 512
# 0 491 14 512
# muchos_obligatorio
# 373 617 393 639
# 373 617 393 639
# uno_obligatorio
# 179 619 196 637
# 179 619 196 637
# uno_obligatorio
# 178 492 197 511
# 178 492 197 511
# uno_obligatorio
# 372 493 390 511
# 372 493 390 511
# uno_obligatorio
# 45 113 62 130
# 45 113 62 130
# uno_obligatorio
# 129 225 146 242
# 129 225 146 242
# uno_obligatorio
# 215 116 230 132
# 215 116 230 132
# uno_obligatorio
# 407 115 424 132
# 407 115 424 132
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000207.png 275 287
# muchos_opcional
# 11 158 33 179
# 11 158 33 179
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000134.png 1188 1019
# muchos_obligatorio
# 231 651 279 692
# 231 651 279 692
# muchos_obligatorio
# 520 374 559 415
# 520 374 559 415
# muchos_obligatorio
# 673 565 709 601
# 673 565 709 601
# muchos_obligatorio
# 962 865 998 902
# 962 865 998 902
# uno_obligatorio
# 229 445 268 485
# 229 445 268 485
# uno_obligatorio
# 375 318 409 353
# 375 318 409 353
# uno_obligatorio
# 478 866 511 899
# 478 866 511 899
# uno_obligatorio
# 391 868 425 902
# 391 868 425 902
# uno_obligatorio
# 673 629 707 658
# 673 629 707 658
# uno_obligatorio
# 873 866 904 899
# 873 866 904 899
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000014.png 196 180
# muchos_obligatorio
# 100 129 116 147
# 100 129 116 147
# uno_obligatorio
# 148 107 164 122
# 148 107 164 122
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000021.png 740 590
# muchos_obligatorio
# 60 580 79 598
# 60 580 79 598
# muchos_obligatorio
# 272 490 291 508
# 272 490 291 508
# muchos_obligatorio
# 189 343 209 362
# 189 343 209 362
# muchos_obligatorio
# 411 139 433 158
# 411 139 433 158
# muchos_obligatorio
# 201 69 220 88
# 201 69 220 88
# uno_obligatorio
# 139 70 155 88
# 139 70 155 88
# uno_obligatorio
# 149 468 166 486
# 149 468 166 486
# uno_obligatorio
# 137 738 154 529
# 137 738 154 529
# a
# uno_obligatorio
# 185 739 202 529
# 185 739 202 529
# a
# uno_obligatorio
# 499 335 514 352
# 499 335 514 352
# uno_obligatorio
# 413 265 431 283
# 413 265 431 283
# uno_obligatorio
# 413 202 432 220
# 413 202 432 220
# uno_obligatorio
# 360 70 376 87
# 360 70 376 87
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000151.png 252 302
# muchos_obligatorio
# 252 149 262 158
# 252 149 262 158
# muchos_obligatorio
# 284 149 293 157
# 284 149 293 157
# muchos_obligatorio
# 244 229 253 238
# 244 229 253 238
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000079.png 590 421
# muchos_obligatorio
# 250 275 273 298
# 250 275 273 298
# uno_obligatorio
# 413 458 301 478
# 413 458 301 478
# a
# uno_obligatorio
# 346 338 366 359
# 346 338 366 359
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000220.png 506 397
# muchos_opcional
# 190 235 217 259
# 190 235 217 259
# muchos_opcional
# 389 276 284 302
# 389 276 284 302
# a
# uno_opcional
# 226 0 250 13
# 226 0 250 13
# uno_opcional
# 225 61 250 88
# 225 61 250 88
# uno_opcional
# 120 151 148 174
# 120 151 148 174
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000225.png 504 596
# muchos_obligatorio
# 146 296 164 311
# 146 296 164 311
# muchos_obligatorio
# 186 442 207 459
# 186 442 207 459
# uno_obligatorio
# 188 296 206 313
# 188 296 206 313
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000029.png 595 723
# muchos_obligatorio
# 543 355 560 374
# 543 355 560 374
# muchos_obligatorio
# 650 357 668 374
# 650 357 668 374
# muchos_obligatorio
# 429 247 447 272
# 429 247 447 272
# uno_obligatorio
# 660 424 681 443
# 660 424 681 443
# uno_obligatorio
# 453 469 473 484
# 453 469 473 484
# uno_obligatorio
# 337 456 356 476
# 337 456 356 476
# uno_obligatorio
# 194 111 216 134
# 194 111 216 134
# uno_obligatorio
# 197 0 215 2
# 197 0 215 2
# uno_obligatorio
# 648 147 670 168
# 648 147 670 168
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000112.png 1730 1054
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000085.png 585 665
# uno_obligatorio
# 435 504 449 517
# 435 504 449 517
# uno_obligatorio
# 602 550 615 562
# 602 550 615 562
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000066.png 662 596
# muchos_obligatorio
# 140 262 157 279
# 140 262 157 279
# muchos_obligatorio
# 48 147 64 164
# 48 147 64 164
# uno_obligatorio
# 265 183 283 205
# 265 183 283 205
# uno_obligatorio
# 137 64 156 81
# 137 64 156 81
# uno_obligatorio
# 48 190 64 205
# 48 190 64 205
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000095.png 529 504
# muchos_obligatorio
# 226 430 247 446
# 226 430 247 446
# muchos_obligatorio
# 409 252 427 270
# 409 252 427 270
# muchos_obligatorio
# 219 166 237 182
# 219 166 237 182
# muchos_obligatorio
# 295 235 314 251
# 295 235 314 251
# muchos_obligatorio
# 432 60 452 76
# 432 60 452 76
# uno_obligatorio
# 152 49 168 63
# 152 49 168 63
# uno_obligatorio
# 199 47 217 63
# 199 47 217 63
# uno_obligatorio
# 183 174 200 190
# 183 174 200 190
# uno_obligatorio
# 307 352 325 368
# 307 352 325 368
# uno_obligatorio
# 391 61 410 76
# 391 61 410 76
# uno_obligatorio
# 474 60 492 77
# 474 60 492 77
# uno_obligatorio
# 493 119 360 135
# 493 119 360 135
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000146.png 361 385
# muchos_obligatorio
# 125 75 146 96
# 125 75 146 96
# muchos_obligatorio
# 125 152 146 173
# 125 152 146 173
# muchos_obligatorio
# 318 302 341 320
# 318 302 341 320
# uno_obligatorio
# 10 115 27 134
# 10 115 27 134
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000023.png 740 590
# muchos_obligatorio
# 33 243 51 262
# 33 243 51 262
# muchos_obligatorio
# 120 322 138 339
# 120 322 138 339
# muchos_obligatorio
# 275 504 294 522
# 275 504 294 522
# muchos_obligatorio
# 503 527 521 544
# 503 527 521 544
# muchos_obligatorio
# 368 402 386 420
# 368 402 386 420
# muchos_obligatorio
# 482 262 501 280
# 482 262 501 280
# muchos_obligatorio
# 273 79 294 98
# 273 79 294 98
# muchos_obligatorio
# 393 118 412 134
# 393 118 412 134
# muchos_obligatorio
# 393 185 413 204
# 393 185 413 204
# uno_obligatorio
# 35 28 53 43
# 35 28 53 43
# uno_obligatorio
# 184 424 201 443
# 184 424 201 443
# uno_obligatorio
# 209 242 226 261
# 209 242 226 261
# uno_obligatorio
# 502 625 520 642
# 502 625 520 642
# uno_obligatorio
# 367 449 383 466
# 367 449 383 466
# uno_obligatorio
# 357 9 374 25
# 357 9 374 25
# uno_obligatorio
# 571 150 588 168
# 571 150 588 168
# uno_obligatorio
# 274 345 297 364
# 274 345 297 364
# uno_obligatorio
# 559 420 576 437
# 559 420 576 437
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000074.png 347 298
# muchos_obligatorio
# 264 142 280 156
# 264 142 280 156
# muchos_obligatorio
# 9 55 22 69
# 9 55 22 69
# muchos_obligatorio
# 36 217 49 231
# 36 217 49 231
# muchos_obligatorio
# 154 218 168 233
# 154 218 168 233
# uno_opcional
# 204 54 218 67
# 204 54 218 67
# uno_opcional
# 264 114 279 127
# 264 114 279 127
# uno_opcional
# 8 217 23 233
# 8 217 23 233
# uno_opcional
# 265 294 280 309
# 265 294 280 309
# uno_opcional
# 185 217 199 232
# 185 217 199 232
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000188.png 362 362
# muchos_opcional
# 185 106 207 129
# 185 106 207 129
# muchos_obligatorio
# 352 108 259 130
# 352 108 259 130
# a
# uno_obligatorio
# 102 113 121 136
# 102 113 121 136
# uno_obligatorio
# 52 183 72 202
# 52 183 72 202
# uno_obligatorio
# 11 183 32 202
# 11 183 32 202
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000006.png 516 637
# muchos_obligatorio
# 191 318 209 337
# 191 318 209 337
# muchos_obligatorio
# 192 247 210 269
# 192 247 210 269
# muchos_obligatorio
# 271 115 290 132
# 271 115 290 132
# uno_opcional
# 91 64 108 84
# 91 64 108 84
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000013.png 196 180
# muchos_obligatorio
# 178 129 129 147
# 178 129 129 147
# a
# uno_obligatorio
# 11 94 27 109
# 11 94 27 109
# uno_obligatorio
# 12 169 27 183
# 12 169 27 183
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000148.png 361 385
# muchos_obligatorio
# 290 0 311 18
# 290 0 311 18
# muchos_obligatorio
# 184 242 203 261
# 184 242 203 261
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000163.png 285 487
# muchos_opcional
# 465 191 348 221
# 465 191 348 221
# a
# uno_obligatorio
# 324 189 352 220
# 324 189 352 220
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000213.png 312 242
# uno_opcional
# 54 180 76 202
# 54 180 76 202
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000083.png 590 421
# muchos_obligatorio
# 293 202 317 225
# 293 202 317 225
# muchos_obligatorio
# 54 459 78 484
# 54 459 78 484
# muchos_obligatorio
# 55 351 80 376
# 55 351 80 376
# muchos_obligatorio
# 69 21 92 44
# 69 21 92 44
# uno_obligatorio
# 232 204 256 224
# 232 204 256 224
# uno_obligatorio
# 165 84 185 105
# 165 84 185 105
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000106.png 959 648
# muchos_obligatorio
# 432 481 452 500
# 432 481 452 500
# muchos_obligatorio
# 164 368 183 386
# 164 368 183 386
# muchos_obligatorio
# 323 262 341 279
# 323 262 341 279
# muchos_obligatorio
# 256 119 275 138
# 256 119 275 138
# uno_obligatorio
# 612 14 631 33
# 612 14 631 33
# uno_obligatorio
# 430 375 447 391
# 430 375 447 391
# uno_obligatorio
# 172 422 192 440
# 172 422 192 440
# uno_obligatorio
# 257 240 274 256
# 257 240 274 256
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000130.png 515 561
# muchos_obligatorio
# 433 273 466 306
# 433 273 466 306
# muchos_obligatorio
# 540 161 401 189
# 540 161 401 189
# a
# uno_obligatorio
# 157 67 189 94
# 157 67 189 94
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000098.png 851 863
# muchos_obligatorio
# 0 361 4 382
# 0 361 4 382
# muchos_obligatorio
# 121 296 140 317
# 121 296 140 317
# muchos_obligatorio
# 222 519 244 539
# 222 519 244 539
# muchos_obligatorio
# 455 363 477 382
# 455 363 477 382
# muchos_obligatorio
# 263 816 283 837
# 263 816 283 837
# uno_opcional
# 575 790 596 811
# 575 790 596 811
# uno_obligatorio
# 0 236 4 255
# 0 236 4 255
# uno_obligatorio
# 48 237 66 255
# 48 237 66 255
# uno_obligatorio
# 119 112 138 132
# 119 112 138 132
# uno_obligatorio
# 119 151 138 170
# 119 151 138 170
# uno_obligatorio
# 118 189 136 207
# 118 189 136 207
# uno_obligatorio
# 354 109 372 125
# 354 109 372 125
# uno_obligatorio
# 354 157 373 177
# 354 157 373 177
# uno_obligatorio
# 458 217 477 235
# 458 217 477 235
# uno_obligatorio
# 225 400 242 418
# 225 400 242 418
# uno_obligatorio
# 335 415 352 433
# 335 415 352 433
# uno_obligatorio
# 334 457 353 474
# 334 457 353 474
# uno_obligatorio
# 89 414 107 435
# 89 414 107 435
# uno_obligatorio
# 88 455 107 475
# 88 455 107 475
# uno_obligatorio
# 90 498 108 517
# 90 498 108 517
# uno_obligatorio
# 166 522 183 537
# 166 522 183 537
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000182.png 278 337
# muchos_opcional
# 154 150 178 172
# 154 150 178 172
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000091.png 529 504
# muchos_obligatorio
# 435 393 453 409
# 435 393 453 409
# uno_obligatorio
# 368 276 384 290
# 368 276 384 290
# uno_obligatorio
# 415 274 433 290
# 415 274 433 290
# uno_obligatorio
# 399 401 416 417
# 399 401 416 417
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000143.png 624 553
# muchos_obligatorio
# 287 382 306 398
# 287 382 306 398
# muchos_obligatorio
# 487 27 507 46
# 487 27 507 46
# uno_obligatorio
# 192 25 210 45
# 192 25 210 45
# uno_obligatorio
# 192 182 209 200
# 192 182 209 200
# uno_obligatorio
# 455 382 471 399
# 455 382 471 399
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000047.png 464 595
# muchos_obligatorio
# 457 0 480 4
# 457 0 480 4
# muchos_obligatorio
# 460 32 480 51
# 460 32 480 51
# muchos_obligatorio
# 458 81 479 100
# 458 81 479 100
# uno_obligatorio
# 235 0 255 16
# 235 0 255 16
# uno_obligatorio
# 245 214 264 235
# 245 214 264 235
# uno_obligatorio
# 245 261 266 283
# 245 261 266 283
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000045.png 464 595
# muchos_obligatorio
# 32 185 55 204
# 32 185 55 204
# muchos_obligatorio
# 35 232 55 251
# 35 232 55 251
# muchos_obligatorio
# 33 281 54 300
# 33 281 54 300
# muchos_obligatorio
# 217 231 239 254
# 217 231 239 254
# muchos_obligatorio
# 439 263 461 284
# 439 263 461 284
# uno_obligatorio
# 439 419 462 438
# 439 419 462 438
# uno_obligatorio
# 361 168 381 188
# 361 168 381 188
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000184.png 278 337
# muchos_opcional
# 299 30 323 52
# 299 30 323 52
# muchos_opcional
# 228 249 252 269
# 228 249 252 269
# muchos_obligatorio
# 101 220 123 238
# 101 220 123 238
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000117.png 369 372
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000204.png 463 519
# muchos_opcional
# 254 0 282 1
# 254 0 282 1
# muchos_opcional
# 207 349 235 379
# 207 349 235 379
# muchos_opcional
# 206 278 235 306
# 206 278 235 306
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000171.png 695 690
# muchos_obligatorio
# 37 253 59 272
# 37 253 59 272
# muchos_obligatorio
# 42 535 58 553
# 42 535 58 553
# uno_obligatorio
# 5 254 25 270
# 5 254 25 270
# uno_obligatorio
# 65 254 89 272
# 65 254 89 272
# uno_obligatorio
# 0 537 10 552
# 0 537 10 552
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000088.png 585 665
# muchos_obligatorio
# 360 337 374 353
# 360 337 374 353
# muchos_obligatorio
# 360 371 374 384
# 360 371 374 384
# muchos_obligatorio
# 360 404 373 418
# 360 404 373 418
# muchos_obligatorio
# 477 347 491 361
# 477 347 491 361
# muchos_obligatorio
# 478 387 493 402
# 478 387 493 402
# muchos_obligatorio
# 478 428 494 444
# 478 428 494 444
# muchos_obligatorio
# 560 457 577 472
# 560 457 577 472
# muchos_obligatorio
# 584 457 599 471
# 584 457 599 471
# muchos_obligatorio
# 607 457 621 471
# 607 457 621 471
# muchos_obligatorio
# 630 457 644 471
# 630 457 644 471
# muchos_obligatorio
# 658 524 475 540
# 658 524 475 540
# a
# uno_obligatorio
# 361 437 374 451
# 361 437 374 451
# uno_obligatorio
# 435 253 449 266
# 435 253 449 266
# uno_obligatorio
# 534 339 547 351
# 534 339 547 351
# uno_obligatorio
# 533 372 547 386
# 533 372 547 386
# uno_obligatorio
# 601 413 614 425
# 601 413 614 425
# uno_obligatorio
# 602 299 615 311
# 602 299 615 311
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000160.png 281 315
# muchos_obligatorio
# 274 155 293 174
# 274 155 293 174
# uno_obligatorio
# 210 44 227 61
# 210 44 227 61
# uno_obligatorio
# 211 127 226 145
# 211 127 226 145
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000118.png 369 372
# muchos_obligatorio
# 110 14 132 32
# 110 14 132 32
# muchos_obligatorio
# 267 39 288 58
# 267 39 288 58
# muchos_obligatorio
# 334 179 354 196
# 334 179 354 196
# uno_opcional
# 111 119 132 139
# 111 119 132 139
# uno_opcional
# 161 119 182 139
# 161 119 182 139
# uno_obligatorio
# 354 142 371 158
# 354 142 371 158
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000175.png 574 467
# muchos_obligatorio
# 399 268 429 296
# 399 268 429 296
# muchos_obligatorio
# 397 457 430 486
# 397 457 430 486
# uno_obligatorio
# 397 222 428 253
# 397 222 428 253
# uno_obligatorio
# 397 533 429 563
# 397 533 429 563
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000125.png 404 310
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000149.png 361 385
# muchos_obligatorio
# 125 0 146 18
# 125 0 146 18
# muchos_obligatorio
# 19 242 38 261
# 19 242 38 261
# muchos_obligatorio
# 318 147 341 165
# 318 147 341 165
# uno_obligatorio
# 237 246 256 266
# 237 246 256 266
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000054.png 371 334
# muchos_opcional
# 252 224 268 241
# 252 224 268 241
# muchos_opcional
# 183 96 201 112
# 183 96 201 112
# uno_opcional
# 10 138 26 154
# 10 138 26 154
# uno_opcional
# 34 223 50 238
# 34 223 50 238
# uno_opcional
# 250 60 267 78
# 250 60 267 78
# uno_obligatorio
# 183 304 200 319
# 183 304 200 319
# uno_obligatorio
# 65 224 79 239
# 65 224 79 239
# uno_obligatorio
# 184 142 199 155
# 184 142 199 155
# uno_obligatorio
# 156 1 173 13
# 156 1 173 13
# uno_obligatorio
# 250 38 267 55
# 250 38 267 55
# uno_obligatorio
# 64 32 80 48
# 64 32 80 48
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000090.png 585 665
# muchos_obligatorio
# 95 326 107 341
# 95 326 107 341
# muchos_obligatorio
# 81 371 94 385
# 81 371 94 385
# muchos_obligatorio
# 7 298 23 311
# 7 298 23 311
# muchos_obligatorio
# 81 435 95 452
# 81 435 95 452
# muchos_obligatorio
# 415 283 430 297
# 415 283 430 297
# muchos_obligatorio
# 414 254 428 268
# 414 254 428 268
# muchos_obligatorio
# 414 226 429 241
# 414 226 429 241
# muchos_obligatorio
# 414 198 429 213
# 414 198 429 213
# muchos_obligatorio
# 415 171 429 185
# 415 171 429 185
# muchos_obligatorio
# 198 44 211 57
# 198 44 211 57
# muchos_obligatorio
# 145 108 160 122
# 145 108 160 122
# uno_obligatorio
# 96 398 107 413
# 96 398 107 413
# uno_obligatorio
# 96 378 107 389
# 96 378 107 389
# uno_obligatorio
# 95 351 107 364
# 95 351 107 364
# uno_obligatorio
# 59 196 70 208
# 59 196 70 208
# uno_obligatorio
# 0 254 9 266
# 0 254 9 266
# uno_obligatorio
# 215 362 229 378
# 215 362 229 378
# uno_obligatorio
# 393 164 406 177
# 393 164 406 177
# uno_obligatorio
# 254 34 268 48
# 254 34 268 48
# uno_obligatorio
# 255 86 269 100
# 255 86 269 100
# uno_obligatorio
# 255 137 268 151
# 255 137 268 151
# uno_obligatorio
# 255 189 268 203
# 255 189 268 203
# uno_obligatorio
# 255 242 267 254
# 255 242 267 254
# uno_obligatorio
# 256 293 268 306
# 256 293 268 306
# uno_obligatorio
# 137 300 150 310
# 137 300 150 310
# uno_obligatorio
# 175 300 186 311
# 175 300 186 311
# uno_obligatorio
# 0 92 8 105
# 0 92 8 105
# uno_obligatorio
# 23 93 35 105
# 23 93 35 105
# uno_obligatorio
# 55 34 68 48
# 55 34 68 48
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000073.png 347 298
# muchos_obligatorio
# 137 55 150 69
# 137 55 150 69
# muchos_obligatorio
# 67 93 82 106
# 67 93 82 106
# muchos_obligatorio
# 164 217 177 231
# 164 217 177 231
# muchos_obligatorio
# 282 218 296 233
# 282 218 296 233
# uno_opcional
# 136 217 151 233
# 136 217 151 233
# uno_opcional
# 66 160 82 175
# 66 160 82 175
# uno_opcional
# 66 274 82 290
# 66 274 82 290
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000093.png 529 504
# muchos_obligatorio
# 49 479 67 497
# 49 479 67 497
# muchos_obligatorio
# 72 287 92 303
# 72 287 92 303
# muchos_obligatorio
# 164 232 184 249
# 164 232 184 249
# muchos_obligatorio
# 275 304 292 324
# 275 304 292 324
# muchos_obligatorio
# 272 378 292 398
# 272 378 292 398
# muchos_obligatorio
# 359 479 379 496
# 359 479 379 496
# uno_obligatorio
# 219 520 236 378
# 219 520 236 378
# a
# uno_obligatorio
# 219 438 235 456
# 219 438 235 456
# uno_obligatorio
# 330 461 346 476
# 330 461 346 476
# uno_obligatorio
# 379 461 395 478
# 379 461 395 478
# uno_obligatorio
# 166 185 183 203
# 166 185 183 203
# uno_obligatorio
# 274 231 291 251
# 274 231 291 251
# uno_obligatorio
# 31 288 50 303
# 31 288 50 303
# uno_obligatorio
# 114 287 132 304
# 114 287 132 304
# uno_obligatorio
# 133 346 152 362
# 133 346 152 362
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000028.png 595 723
# muchos_obligatorio
# 81 288 97 305
# 81 288 97 305
# muchos_obligatorio
# 169 285 192 306
# 169 285 192 306
# muchos_obligatorio
# 272 160 295 183
# 272 160 295 183
# muchos_obligatorio
# 124 95 148 118
# 124 95 148 118
# uno_obligatorio
# 648 456 667 476
# 648 456 667 476
# uno_obligatorio
# 276 396 298 416
# 276 396 298 416
# uno_obligatorio
# 83 330 101 346
# 83 330 101 346
# uno_obligatorio
# 271 217 293 241
# 271 217 293 241
# uno_obligatorio
# 505 111 527 134
# 505 111 527 134
# uno_obligatorio
# 91 20 108 40
# 91 20 108 40
# uno_obligatorio
# 508 0 526 2
# 508 0 526 2
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000119.png 369 372
# muchos_obligatorio
# 107 39 128 58
# 107 39 128 58
# muchos_obligatorio
# 174 179 194 196
# 174 179 194 196
# muchos_obligatorio
# 246 230 264 248
# 246 230 264 248
# uno_opcional
# 1 119 22 139
# 1 119 22 139
# uno_obligatorio
# 194 142 211 158
# 194 142 211 158
# uno_obligatorio
# 315 257 334 275
# 315 257 334 275
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000114.png 1730 1054
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000121.png 404 310
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000162.png 281 315
# muchos_obligatorio
# 88 156 104 174
# 88 156 104 174
# uno_obligatorio
# 139 159 153 175
# 139 159 153 175
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000206.png 275 287
# muchos_opcional
# 59 108 80 131
# 59 108 80 131
# muchos_opcional
# 216 158 238 179
# 216 158 238 179
# uno_opcional
# 119 219 140 239
# 119 219 140 239
# uno_opcional
# 168 219 190 239
# 168 219 190 239
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000018.png 196 180
# muchos_obligatorio
# 95 101 115 116
# 95 101 115 116
# uno_obligatorio
# 19 23 35 38
# 19 23 35 38
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000031.png 345 240
# muchos_opcional
# 154 199 174 217
# 154 199 174 217
# muchos_opcional
# 75 304 95 323
# 75 304 95 323
# muchos_obligatorio
# 154 51 171 68
# 154 51 171 68
# uno_opcional
# 155 152 173 168
# 155 152 173 168
# uno_obligatorio
# 77 260 94 276
# 77 260 94 276
# uno_obligatorio
# 153 100 169 119
# 153 100 169 119
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000229.png 186 271
# muchos_obligatorio
# 157 121 175 140
# 157 121 175 140
# uno_obligatorio
# 216 68 231 84
# 216 68 231 84
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000158.png 281 315
# muchos_obligatorio
# 138 73 155 90
# 138 73 155 90
# muchos_obligatorio
# 139 276 158 201
# 139 276 158 201
# a
# muchos_obligatorio
# 313 277 225 201
# 313 277 225 201
# a
# uno_obligatorio
# 75 165 92 182
# 75 165 92 182
# uno_obligatorio
# 76 248 91 266
# 76 248 91 266
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000131.png 515 561
# muchos_obligatorio
# 192 273 225 306
# 192 273 225 306
# muchos_obligatorio
# 299 161 334 189
# 299 161 334 189
# uno_obligatorio
# 491 66 524 93
# 491 66 524 93
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000237.png 541 396
# muchos_obligatorio
# 59 532 92 387
# 59 532 92 387
# a
# muchos_obligatorio
# 337 411 375 451
# 337 411 375 451
# muchos_obligatorio
# 173 85 200 108
# 173 85 200 108
# uno_obligatorio
# 101 83 125 110
# 101 83 125 110
# uno_obligatorio
# 146 419 176 445
# 146 419 176 445
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000177.png 574 467
# uno_opcional
# 248 284 280 318
# 248 284 280 318
# uno_opcional
# 246 348 279 383
# 246 348 279 383
# uno_obligatorio
# 12 87 40 119
# 12 87 40 119
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000227.png 504 596
# muchos_obligatorio
# 239 175 258 191
# 239 175 258 191
# muchos_obligatorio
# 240 80 260 95
# 240 80 260 95
# muchos_obligatorio
# 572 80 590 95
# 572 80 590 95
# uno_obligatorio
# 105 236 121 253
# 105 236 121 253
# uno_obligatorio
# 102 58 116 74
# 102 58 116 74
# uno_obligatorio
# 102 0 115 16
# 102 0 115 16
# uno_obligatorio
# 289 364 305 380
# 289 364 305 380
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000168.png 285 487
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000019.png 740 590
# muchos_obligatorio
# 69 233 90 251
# 69 233 90 251
# muchos_obligatorio
# 149 162 169 184
# 149 162 169 184
# muchos_obligatorio
# 130 350 151 369
# 130 350 151 369
# muchos_obligatorio
# 201 478 219 496
# 201 478 219 496
# muchos_obligatorio
# 287 561 305 580
# 287 561 305 580
# muchos_obligatorio
# 374 640 392 657
# 374 640 392 657
# muchos_obligatorio
# 527 397 548 416
# 527 397 548 416
# uno_obligatorio
# 226 116 243 135
# 226 116 243 135
# uno_obligatorio
# 211 278 229 295
# 211 278 229 295
# uno_obligatorio
# 71 353 89 369
# 71 353 89 369
# uno_obligatorio
# 289 346 307 361
# 289 346 307 361
# uno_obligatorio
# 200 598 216 615
# 200 598 216 615
# uno_obligatorio
# 101 727 119 529
# 101 727 119 529
# a
# uno_obligatorio
# 463 560 480 579
# 463 560 480 579
# uno_obligatorio
# 528 663 551 682
# 528 663 551 682
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000105.png 959 648
# muchos_obligatorio
# 511 562 532 581
# 511 562 532 581
# muchos_obligatorio
# 200 200 218 218
# 200 200 218 218
# uno_obligatorio
# 499 452 517 468
# 499 452 517 468
# uno_obligatorio
# 11 236 30 255
# 11 236 30 255
# uno_obligatorio
# 200 275 218 294
# 200 275 218 294
# ...
# muchos_opcional
# 183 255 201 271
# 183 255 201 271
# uno_opcional
# 10 297 26 313
# 10 297 26 313
# uno_opcional
# 250 219 267 237
# 250 219 267 237
# uno_obligatorio
# 184 301 199 314
# 184 301 199 314
# uno_obligatorio
# 156 160 173 172
# 156 160 173 172
# uno_obligatorio
# 250 197 267 214
# 250 197 267 214
# uno_obligatorio
# 64 191 80 207
# 64 191 80 207
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000159.png 281 315
# muchos_obligatorio
# 88 277 104 201
# 88 277 104 201
# a
# uno_obligatorio
# 139 280 153 201
# 139 280 153 201
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000169.png 695 690
# muchos_obligatorio
# 563 253 586 273
# 563 253 586 273
# muchos_obligatorio
# 455 368 475 387
# 455 368 475 387
# muchos_obligatorio
# 372 470 393 488
# 372 470 393 488
# muchos_obligatorio
# 395 666 414 682
# 395 666 414 682
# muchos_obligatorio
# 349 666 366 682
# 349 666 366 682
# uno_obligatorio
# 612 254 630 271
# 612 254 630 271
# uno_obligatorio
# 454 415 473 433
# 454 415 473 433
# uno_obligatorio
# 586 532 607 549
# 586 532 607 549
# uno_obligatorio
# 178 665 197 682
# 178 665 197 682
# uno_obligatorio
# 131 666 151 685
# 131 666 151 685
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000026.png 595 723
# muchos_obligatorio
# 429 502 447 527
# 429 502 447 527
# muchos_obligatorio
# 7 167 29 189
# 7 167 29 189
# muchos_obligatorio
# 123 63 145 88
# 123 63 145 88
# muchos_obligatorio
# 122 111 142 134
# 122 111 142 134
# uno_obligatorio
# 194 366 216 389
# 194 366 216 389
# uno_obligatorio
# 197 239 215 257
# 197 239 215 257
# uno_obligatorio
# 648 402 670 423
# 648 402 670 423
# uno_obligatorio
# 674 76 692 98
# 674 76 692 98
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000120.png 369 372
# uno_obligatorio
# 49 257 68 275
# 49 257 68 275
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000153.png 252 302
# muchos_obligatorio
# 101 196 110 204
# 101 196 110 204
# uno_obligatorio
# 57 241 66 249
# 57 241 66 249
# uno_obligatorio
# 62 97 70 106
# 62 97 70 106
# uno_obligatorio
# 107 128 117 136
# 107 128 117 136
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000239.png 541 396
# muchos_obligatorio
# 6 272 36 299
# 6 272 36 299
# muchos_obligatorio
# 171 272 198 300
# 171 272 198 300
# muchos_obligatorio
# 200 355 227 386
# 200 355 227 386
# muchos_obligatorio
# 342 299 375 328
# 342 299 375 328
# uno_obligatorio
# 9 126 34 149
# 9 126 34 149
# uno_obligatorio
# 171 124 198 149
# 171 124 198 149
# uno_obligatorio
# 312 359 338 388
# 312 359 338 388
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000030.png 595 723
# muchos_obligatorio
# 352 252 373 273
# 352 252 373 273
# muchos_obligatorio
# 26 355 43 374
# 26 355 43 374
# muchos_obligatorio
# 133 357 151 374
# 133 357 151 374
# muchos_obligatorio
# 235 356 258 376
# 235 356 258 376
# uno_obligatorio
# 374 336 393 359
# 374 336 393 359
# uno_obligatorio
# 143 424 164 443
# 143 424 164 443
# uno_obligatorio
# 131 147 153 168
# 131 147 153 168
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000065.png 662 596
# muchos_obligatorio
# 566 262 583 279
# 566 262 583 279
# muchos_obligatorio
# 380 63 400 82
# 380 63 400 82
# muchos_obligatorio
# 474 147 490 164
# 474 147 490 164
# uno_obligatorio
# 274 149 292 166
# 274 149 292 166
# uno_obligatorio
# 563 64 582 81
# 563 64 582 81
# uno_obligatorio
# 474 190 490 205
# 474 190 490 205
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000048.png 464 595
# muchos_obligatorio
# 32 0 55 4
# 32 0 55 4
# muchos_obligatorio
# 35 32 55 51
# 35 32 55 51
# muchos_obligatorio
# 33 81 54 100
# 33 81 54 100
# muchos_obligatorio
# 217 31 239 54
# 217 31 239 54
# muchos_obligatorio
# 439 63 461 84
# 439 63 461 84
# uno_obligatorio
# 439 219 462 238
# 439 219 462 238
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000156.png 252 302
# muchos_obligatorio
# 57 173 66 183
# 57 173 66 183
# muchos_obligatorio
# 101 88 110 96
# 101 88 110 96
# uno_obligatorio
# 57 133 66 141
# 57 133 66 141
# uno_obligatorio
# 107 20 117 28
# 107 20 117 28
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000039.png 492 541
# muchos_obligatorio
# 252 455 273 475
# 252 455 273 475
# uno_obligatorio
# 18 331 39 349
# 18 331 39 349
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000172.png 695 690
# muchos_obligatorio
# 455 69 475 88
# 455 69 475 88
# muchos_obligatorio
# 372 171 393 189
# 372 171 393 189
# muchos_obligatorio
# 675 562 493 576
# 675 562 493 576
# a
# muchos_obligatorio
# 589 448 610 467
# 589 448 610 467
# muchos_obligatorio
# 395 367 414 383
# 395 367 414 383
# muchos_obligatorio
# 349 367 366 383
# 349 367 366 383
# muchos_obligatorio
# 512 559 529 577
# 512 559 529 577
# muchos_obligatorio
# 294 570 312 588
# 294 570 312 588
# muchos_obligatorio
# 238 555 256 572
# 238 555 256 572
# uno_obligatorio
# 454 116 473 134
# 454 116 473 134
# uno_obligatorio
# 586 233 607 250
# 586 233 607 250
# uno_obligatorio
# 362 450 379 466
# 362 450 379 466
# uno_obligatorio
# 421 452 440 467
# 421 452 440 467
# uno_obligatorio
# 178 366 197 383
# 178 366 197 383
# uno_obligatorio
# 131 367 151 386
# 131 367 151 386
# uno_obligatorio
# 238 504 257 525
# 238 504 257 525
# uno_obligatorio
# 238 605 256 624
# 238 605 256 624
# uno_obligatorio
# 239 652 257 670
# 239 652 257 670
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000214.png 312 242
# muchos_opcional
# 211 202 233 223
# 211 202 233 223
# muchos_opcional
# 114 44 137 65
# 114 44 137 65
# uno_opcional
# 115 123 137 143
# 115 123 137 143
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000001.png 516 637
# muchos_obligatorio
# 552 286 570 305
# 552 286 570 305
# muchos_obligatorio
# 483 355 501 372
# 483 355 501 372
# uno_obligatorio
# 482 474 503 492
# 482 474 503 492
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000070.png 722 438
# muchos_obligatorio
# 83 82 106 102
# 83 82 106 102
# muchos_obligatorio
# 181 181 202 202
# 181 181 202 202
# muchos_obligatorio
# 161 456 180 478
# 161 456 180 478
# muchos_obligatorio
# 432 443 313 461
# 432 443 313 461
# a
# uno_obligatorio
# 385 577 404 594
# 385 577 404 594
# uno_obligatorio
# 367 309 384 327
# 367 309 384 327
# uno_obligatorio
# 366 182 385 201
# 366 182 385 201
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000008.png 504 596
# muchos_obligatorio
# 248 497 263 360
# 248 497 263 360
# a
# muchos_obligatorio
# 491 438 510 459
# 491 438 510 459
# muchos_obligatorio
# 343 389 361 405
# 343 389 361 405
# muchos_obligatorio
# 394 389 409 404
# 394 389 409 404
# muchos_obligatorio
# 399 427 416 443
# 399 427 416 443
# uno_obligatorio
# 377 162 395 178
# 377 162 395 178
# uno_obligatorio
# 492 335 508 351
# 492 335 508 351
# uno_obligatorio
# 346 426 364 442
# 346 426 364 442
# uno_obligatorio
# 166 253 183 269
# 166 253 183 269
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000103.png 959 648
# muchos_obligatorio
# 612 144 630 164
# 612 144 630 164
# muchos_obligatorio
# 612 238 630 257
# 612 238 630 257
# muchos_obligatorio
# 432 892 452 911
# 432 892 452 911
# muchos_obligatorio
# 164 779 183 797
# 164 779 183 797
# muchos_obligatorio
# 323 673 341 690
# 323 673 341 690
# muchos_obligatorio
# 269 232 289 250
# 269 232 289 250
# muchos_obligatorio
# 256 530 275 549
# 256 530 275 549
# uno_obligatorio
# 613 333 629 350
# 613 333 629 350
# uno_obligatorio
# 612 425 631 444
# 612 425 631 444
# uno_obligatorio
# 430 786 447 802
# 430 786 447 802
# uno_obligatorio
# 172 833 192 851
# 172 833 192 851
# uno_obligatorio
# 257 651 274 667
# 257 651 274 667
# uno_obligatorio
# 403 364 420 380
# 403 364 420 380
# uno_obligatorio
# 401 208 420 224
# 401 208 420 224
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000139.png 624 553
# uno_obligatorio
# 429 293 447 313
# 429 293 447 313
# uno_obligatorio
# 429 450 446 468
# 429 450 446 468
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000046.png 464 595
# uno_obligatorio
# 490 0 510 16
# 490 0 510 16
# uno_obligatorio
# 500 214 519 235
# 500 214 519 235
# uno_obligatorio
# 500 261 521 283
# 500 261 521 283
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000060.png 442 442
# muchos_obligatorio
# 0 258 4 285
# 0 258 4 285
# uno_obligatorio
# 130 258 156 283
# 130 258 156 283
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000181.png 278 337
# muchos_opcional
# 299 150 323 172
# 299 150 323 172
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000096.png 529 504
# muchos_obligatorio
# 49 252 67 270
# 49 252 67 270
# muchos_obligatorio
# 72 60 92 76
# 72 60 92 76
# muchos_obligatorio
# 164 5 184 22
# 164 5 184 22
# muchos_obligatorio
# 275 77 292 97
# 275 77 292 97
# muchos_obligatorio
# 272 151 292 171
# 272 151 292 171
# muchos_obligatorio
# 359 252 379 269
# 359 252 379 269
# uno_obligatorio
# 219 293 236 311
# 219 293 236 311
# uno_obligatorio
# 219 211 235 229
# 219 211 235 229
# uno_obligatorio
# 330 234 346 249
# 330 234 346 249
# uno_obligatorio
# 379 234 395 251
# 379 234 395 251
# uno_obligatorio
# 274 4 291 24
# 274 4 291 24
# uno_obligatorio
# 31 61 50 76
# 31 61 50 76
# uno_obligatorio
# 114 60 132 77
# 114 60 132 77
# uno_obligatorio
# 133 119 152 135
# 133 119 152 135
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000049.png 371 334
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000145.png 361 385
# muchos_obligatorio
# 290 75 311 96
# 290 75 311 96
# muchos_obligatorio
# 290 152 311 173
# 290 152 311 173
# uno_obligatorio
# 175 115 192 134
# 175 115 192 134
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000224.png 504 596
# muchos_obligatorio
# 239 391 258 407
# 239 391 258 407
# muchos_obligatorio
# 240 296 260 311
# 240 296 260 311
# muchos_obligatorio
# 572 296 590 311
# 572 296 590 311
# uno_obligatorio
# 105 452 121 469
# 105 452 121 469
# uno_obligatorio
# 102 274 116 290
# 102 274 116 290
# uno_obligatorio
# 102 216 115 232
# 102 216 115 232
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000027.png 595 723
# muchos_obligatorio
# 343 147 364 167
# 343 147 364 167
# muchos_obligatorio
# 252 148 274 168
# 252 148 274 168
# muchos_obligatorio
# 352 507 373 528
# 352 507 373 528
# uno_obligatorio
# 488 168 508 189
# 488 168 508 189
# uno_obligatorio
# 298 208 322 228
# 298 208 322 228
# uno_obligatorio
# 374 591 393 425
# 374 591 393 425
# a
# uno_obligatorio
# 131 402 153 423
# 131 402 153 423
# uno_obligatorio
# 157 76 175 98
# 157 76 175 98
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000017.png 196 180
# muchos_obligatorio
# 100 45 116 63
# 100 45 116 63
# uno_obligatorio
# 148 23 164 38
# 148 23 164 38
# uno_obligatorio
# 17 170 32 183
# 17 170 32 183
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000157.png 281 315
# muchos_obligatorio
# 273 73 290 90
# 273 73 290 90
# muchos_obligatorio
# 274 276 293 201
# 274 276 293 201
# a
# uno_obligatorio
# 210 165 227 182
# 210 165 227 182
# uno_obligatorio
# 211 248 226 266
# 211 248 226 266
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000136.png 1188 1019
# muchos_obligatorio
# 668 141 716 182
# 668 141 716 182
# uno_obligatorio
# 915 356 948 389
# 915 356 948 389
# uno_obligatorio
# 828 358 862 392
# 828 358 862 392
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000240.png 541 396
# muchos_obligatorio
# 59 299 92 328
# 59 299 92 328
# muchos_obligatorio
# 337 178 375 218
# 337 178 375 218
# uno_obligatorio
# 29 359 55 388
# 29 359 55 388
# uno_obligatorio
# 146 186 176 212
# 146 186 176 212
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000080.png 590 421
# muchos_obligatorio
# 293 456 317 479
# 293 456 317 479
# muchos_obligatorio
# 261 223 288 244
# 261 223 288 244
# muchos_obligatorio
# 69 275 92 298
# 69 275 92 298
# uno_obligatorio
# 232 458 256 478
# 232 458 256 478
# uno_obligatorio
# 165 338 185 359
# 165 338 185 359
# uno_obligatorio
# 264 110 287 130
# 264 110 287 130
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000071.png 722 438
# muchos_obligatorio
# 273 47 296 66
# 273 47 296 66
# muchos_obligatorio
# 0 181 14 202
# 0 181 14 202
# muchos_obligatorio
# 244 443 266 461
# 244 443 266 461
# muchos_obligatorio
# 304 442 325 460
# 304 442 325 460
# muchos_obligatorio
# 373 307 393 329
# 373 307 393 329
# uno_obligatorio
# 197 577 216 594
# 197 577 216 594
# uno_obligatorio
# 363 579 381 595
# 363 579 381 595
# uno_obligatorio
# 179 309 196 327
# 179 309 196 327
# uno_obligatorio
# 178 182 197 201
# 178 182 197 201
# uno_obligatorio
# 372 183 390 201
# 372 183 390 201
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000150.png 361 385
# muchos_obligatorio
# 43 147 66 165
# 43 147 66 165
# muchos_obligatorio
# 204 56 224 74
# 204 56 224 74
# uno_obligatorio
# 153 56 172 74
# 153 56 172 74
# uno_obligatorio
# 272 153 291 170
# 272 153 291 170
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000128.png 515 561
# muchos_obligatorio
# 192 494 225 368
# 192 494 225 368
# a
# muchos_obligatorio
# 299 382 334 410
# 299 382 334 410
# uno_obligatorio
# 491 287 524 314
# 491 287 524 314
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000133.png 1188 1019
# muchos_obligatorio
# 668 651 716 692
# 668 651 716 692
# muchos_obligatorio
# 957 374 996 415
# 957 374 996 415
# uno_obligatorio
# 666 445 705 485
# 666 445 705 485
# uno_obligatorio
# 812 318 846 353
# 812 318 846 353
# uno_obligatorio
# 915 866 948 899
# 915 866 948 899
# uno_obligatorio
# 828 868 862 902
# 828 868 862 902
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000043.png 464 595
# uno_obligatorio
# 490 194 510 216
# 490 194 510 216
# uno_obligatorio
# 500 414 519 435
# 500 414 519 435
# uno_obligatorio
# 500 461 521 332
# 500 461 521 332
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000198.png 599 547
# muchos_opcional
# 43 448 74 482
# 43 448 74 482
# muchos_opcional
# 222 291 256 324
# 222 291 256 324
# muchos_opcional
# 128 45 162 77
# 128 45 162 77
# muchos_opcional
# 320 182 352 213
# 320 182 352 213
# muchos_opcional
# 209 47 242 76
# 209 47 242 76
# uno_opcional
# 0 0 18 5
# 0 0 18 5
# uno_opcional
# 281 184 309 212
# 281 184 309 212
# uno_opcional
# 130 366 159 394
# 130 366 159 394
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000193.png 599 547
# muchos_opcional
# 327 230 359 263
# 327 230 359 263
# muchos_opcional
# 237 338 269 368
# 237 338 269 368
# muchos_opcional
# 465 407 497 436
# 465 407 497 436
# uno_opcional
# 426 231 452 260
# 426 231 452 260
# uno_opcional
# 517 317 391 346
# 517 317 391 346
# a
# uno_opcional
# 355 524 383 553
# 355 524 383 553
# uno_opcional
# 81 519 114 549
# 81 519 114 549
# uno_opcional
# 162 339 193 369
# 162 339 193 369
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000086.png 585 665
# muchos_obligatorio
# 570 577 582 418
# 570 577 582 418
# a
# muchos_obligatorio
# 482 549 498 562
# 482 549 498 562
# muchos_obligatorio
# 381 463 393 477
# 381 463 393 477
# muchos_obligatorio
# 620 359 635 373
# 620 359 635 373
# muchos_obligatorio
# 491 230 504 241
# 491 230 504 241
# muchos_obligatorio
# 453 231 465 242
# 453 231 465 242
# muchos_obligatorio
# 533 149 546 165
# 533 149 546 165
# uno_obligatorio
# 150 504 164 517
# 150 504 164 517
# uno_obligatorio
# 386 580 400 418
# 386 580 400 418
# a
# uno_obligatorio
# 534 447 545 459
# 534 447 545 459
# uno_obligatorio
# 472 505 484 517
# 472 505 484 517
# uno_obligatorio
# 410 446 423 459
# 410 446 423 459
# uno_obligatorio
# 317 550 330 562
# 317 550 330 562
# uno_obligatorio
# 612 551 625 561
# 612 551 625 561
# uno_obligatorio
# 650 551 661 562
# 650 551 661 562
# uno_obligatorio
# 443 343 456 355
# 443 343 456 355
# uno_obligatorio
# 470 343 483 356
# 470 343 483 356
# uno_obligatorio
# 498 344 510 356
# 498 344 510 356
# uno_obligatorio
# 530 285 543 299
# 530 285 543 299
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000205.png 275 287
# muchos_opcional
# 182 108 203 131
# 182 108 203 131
# uno_opcional
# 242 219 263 239
# 242 219 263 239
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000222.png 506 397
# uno_opcional
# 95 45 121 67
# 95 45 121 67
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000059.png 442 442
# muchos_obligatorio
# 296 258 320 285
# 296 258 320 285
# uno_obligatorio
# 17 98 40 123
# 17 98 40 123
# uno_obligatorio
# 17 21 39 42
# 17 21 39 42
# uno_obligatorio
# 122 259 147 285
# 122 259 147 285
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000189.png 362 362
# muchos_obligatorio
# 93 108 114 130
# 93 108 114 130
# uno_obligatorio
# 171 91 191 111
# 171 91 191 111
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000116.png 369 372
# muchos_obligatorio
# 31 91 52 112
# 31 91 52 112
# muchos_obligatorio
# 107 198 128 217
# 107 198 128 217
# muchos_obligatorio
# 174 338 194 355
# 174 338 194 355
# uno_opcional
# 1 278 22 298
# 1 278 22 298
# uno_opcional
# 105 103 127 123
# 105 103 127 123
# uno_obligatorio
# 194 301 211 317
# 194 301 211 317
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000109.png 1730 1054
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000234.png 186 271
# muchos_obligatorio
# 62 0 78 5
# 62 0 78 5
# uno_obligatorio
# 107 0 124 6
# 107 0 124 6
#                                           image_path  xmin  ymin  xmax  ymax  \
# 0  /home/nacho/TFI-Cazcarra/data/tiles/image_slic...   279    64   297    83
# 1  /home/nacho/TFI-Cazcarra/data/tiles/image_slic...   210   133   228   150
# 2  /home/nacho/TFI-Cazcarra/data/tiles/image_slic...   546    64   563    84
# 3  /home/nacho/TFI-Cazcarra/data/tiles/image_slic...   283   317   302   337
# 4  /home/nacho/TFI-Cazcarra/data/tiles/image_slic...   384    65   400    83
#
#                 label
# 0  muchos_obligatorio
# 1  muchos_obligatorio
# 2        uno_opcional
# 3        uno_opcional
# 4     uno_obligatorio

# %%
get_val_count(csv)
# Out:
# uno_obligatorio       579
# muchos_obligatorio    495
# uno_opcional          134
# muchos_opcional        87
# Name: label, dtype: int64

# %%
mapper = pd.read_csv("../data/tiles/mapper.csv")
mapper.columns = ["image_name","tile1","tile2","tile3","tile4","tile5","tile6"]

for c in mapper.columns[1:]:
    mapper[c] = mapper[c].apply(lambda x: str(x).zfill(6))

# %%
mapper.head()
# Out:
#            image_name   tile1   tile2   tile3   tile4   tile5   tile6
# 0   ERDiagramsMySQL-1  000001  000002  000003  000004  000005  000006
# 1  ERDiagramsMySQL-10  000007  000008  000009  000010  000011  000012
# 2  ERDiagramsMySQL-11  000013  000014  000015  000016  000017  000018
# 3  ERDiagramsMySQL-12  000019  000020  000021  000022  000023  000024
# 4  ERDiagramsMySQL-13  000025  000026  000027  000028  000029  000030

# %%
train_original = pd.read_csv("../data/csv/train_diagramas_linux.csv")
train_images = train_original.image_path.unique()
train_images = [img_path.split(os.sep)[-1].split(".")[0] for img_path in train_images]

# %%
train_sliced = csv[csv['image_path'].isin(train_images)]
test_sliced = csv[~csv['image_path'].isin(train_images)]

# %%
def get_original_image(slice_path, mapper=mapper):
    img_path = slice_path.split(os.sep)[-1]
    img_path = img_path.split(".")[0]
    mapper = mapper.set_index("image_name")
    mapper_t = mapper.T
    for c in mapper_t.columns:
        if img_path in mapper_t[c].values:
            return c
    return None

csv['original_img_path'] = csv['image_path'].apply(lambda x: get_original_image(x))
csv.head()
# Out:
#                                           image_path  xmin  ymin  xmax  ymax  \
# 0  /home/nacho/TFI-Cazcarra/data/tiles/image_slic...   279    64   297    83
# 1  /home/nacho/TFI-Cazcarra/data/tiles/image_slic...   210   133   228   150
# 2  /home/nacho/TFI-Cazcarra/data/tiles/image_slic...   546    64   563    84
# 3  /home/nacho/TFI-Cazcarra/data/tiles/image_slic...   283   317   302   337
# 4  /home/nacho/TFI-Cazcarra/data/tiles/image_slic...   384    65   400    83
#
#                 label  original_img_path
# 0  muchos_obligatorio  ERDiagramsMySQL-1
# 1  muchos_obligatorio  ERDiagramsMySQL-1
# 2        uno_opcional  ERDiagramsMySQL-1
# 3        uno_opcional  ERDiagramsMySQL-1
# 4     uno_obligatorio  ERDiagramsMySQL-1

# %%
train_sliced = csv[csv['original_img_path'].isin(train_images)]
test_sliced = csv[~csv['original_img_path'].isin(train_images)]

# %%
print(train_sliced.shape)
print(test_sliced.shape)
# Out:
# (985, 7)
# (310, 7)

# %%
train_sliced.drop(columns=["original_img_path"]).to_csv(f"{PATH}/data/tiles/train_cardinalidades_linux.csv")
test_sliced.drop(columns=["original_img_path"]).to_csv(f"{PATH}/data/tiles/test_cardinalidades_linux.csv")

# %%
train_sliced.head(6)
# Out:
#                                           image_path  xmin  ymin  xmax  ymax  \
# 0  /home/nacho/TFI-Cazcarra/data/tiles/image_slic...   279    64   297    83
# 1  /home/nacho/TFI-Cazcarra/data/tiles/image_slic...   210   133   228   150
# 2  /home/nacho/TFI-Cazcarra/data/tiles/image_slic...   546    64   563    84
# 3  /home/nacho/TFI-Cazcarra/data/tiles/image_slic...   283   317   302   337
# 4  /home/nacho/TFI-Cazcarra/data/tiles/image_slic...   384    65   400    83
# 5  /home/nacho/TFI-Cazcarra/data/tiles/image_slic...   209   252   230   270
#
#                 label  original_img_path
# 0  muchos_obligatorio  ERDiagramsMySQL-1
# 1  muchos_obligatorio  ERDiagramsMySQL-1
# 2        uno_opcional  ERDiagramsMySQL-1
# 3        uno_opcional  ERDiagramsMySQL-1
# 4     uno_obligatorio  ERDiagramsMySQL-1
# 5     uno_obligatorio  ERDiagramsMySQL-1
