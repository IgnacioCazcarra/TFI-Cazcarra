# %%
from glob import glob
import random
import os
import xml.etree.ElementTree as ET
import shutil
import numpy as np
import pandas as pd

from PIL import Image

# %%
import sys
sys.path.append("../")

from src.constants import *

# %%
BASE_DIR_IMG = f"{PATH}/data/tiles/image_slices/"
BASE_DIR_XML = f"{PATH}/data/tiles/xml_slices/"

CSV = f"{PATH}/data/tiles/data_cardinalidades_sliced.csv"

# %%
FILES = glob(BASE_DIR_XML+"*.xml") + glob(BASE_DIR_IMG+"*.png") + glob(os.path.join(BASE_DIR_IMG,"*.jpg"))
IMAGES = glob(os.path.join(BASE_DIR_IMG,"*.png")) + glob(os.path.join(BASE_DIR_IMG,"*.jpg"))

# %%
CLASSES = ['muchos_opcional','muchos_obligatorio','uno_opcional','uno_obligatorio']

# %%
def generate_train_test(dataset, sep="/"):    
    for (dtype, image_paths, output_csv) in dataset:
        print ("[INFO] creating '{}' set...".format(dtype))
        print ("[INFO] {} total images in '{}' set".format(len(image_paths), dtype))

        csv = open(output_csv, "w")
        
        header_row = ["image_path","xmin", "ymin", "xmax", "ymax", "label"]
        csv.write("{}\n".format(",".join(header_row)))
        
        for image_path in image_paths:
            fname = image_path.split(sep)[-1]
            fname = fname[:fname.rfind(".")]+".xml"
            annot_path = BASE_DIR_XML + fname
            tree = ET.parse(annot_path)
            root = tree.getroot()
            size = root.find("size")
#             h = int(size.find("height").text)
#             w = int(size.find("width").text)

            w,h = Image.open(image_path).size
            print(image_path, w, h)
            
            for label in CLASSES:
                for o in tree.iter("object"):
                    if o.find("name").text==label:
                        box = o.find("bndbox")
                        xmin = int(box.find("xmin").text)
                        ymin = int(box.find("ymin").text)
                        xmax = int(box.find("xmax").text)
                        ymax = int(box.find("ymax").text)
                        # truncate any bounding box coordinates that fall outside
                        # the boundaries of the image
                        xmin = max(0, xmin)
                        ymin = max(0, ymin)
                        xmax = min(w, xmax)
                        ymax = min(h, ymax)

                        # ignore the bounding boxes where the minimum values are larger
                        # than the maximum values and vice-versa due to annotation errors
                        if xmin >= xmax or ymin >= ymax:
                            print("a")
                            continue
                        elif xmax <= xmin or ymax <= ymin:
                            print("b")
                            continue

                        row = [os.path.abspath(image_path),str(xmin), str(ymin), str(xmax), str(ymax), str(label)]
                        csv.write("{}\n".format(",".join(row)))
        csv.close()

# %%
def split_wrapper():    
    dataset = [("csv", IMAGES, CSV)]
    #Create and write train and test csv
    generate_train_test(dataset)

# %%
def get_val_count(df):
    return df[df.columns[-1]].value_counts()

split_wrapper()

csv = pd.read_csv(CSV)
csv.head()
# Out:
# [INFO] creating 'csv' set...
# [INFO] 462 total images in 'csv' set
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000413.png 1465 1407
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000005.png 637 516
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000403.png 774 704
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000094.png 504 529
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000273.png 215 421
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000429.png 277 383
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000341.png 637 537
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000212.png 242 312
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000383.png 581 541
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000396.png 606 421
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000089.png 665 585
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000072.png 438 722
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000185.png 337 278
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000247.png 485 347
# a
# a
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000421.png 721 651
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000202.png 519 463
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000087.png 665 585
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000235.png 396 541
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000353.png 877 673
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000274.png 215 421
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000192.png 362 362
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000053.png 334 371
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000033.png 240 345
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000061.png 596 662
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000458.png 303 205
# a
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000084.png 421 590
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000165.png 487 285
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000152.png 302 252
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000044.png 595 464
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000004.png 637 516
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000076.png 298 347
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000142.png 553 624
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000186.png 337 278
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000180.png 467 574
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000211.png 242 312
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000437.png 280 308
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000216.png 242 312
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000401.png 674 523
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000381.png 581 541
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000097.png 863 851
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000409.png 1465 1407
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000055.png 442 442
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000423.png 721 651
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000034.png 240 345
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000022.png 590 740
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000104.png 648 959
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000332.png 372 541
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000154.png 302 252
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000092.png 504 529
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000178.png 467 574
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000254.png 263 246
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000122.png 310 404
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000428.png 277 383
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000082.png 421 590
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000179.png 467 574
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000077.png 298 347
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000132.png 561 515
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000042.png 541 492
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000268.png 372 406
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000352.png 877 673
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000199.png 519 463
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000102.png 863 851
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000250.png 485 347
# a
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000364.png 642 749
# a
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000197.png 547 599
# a
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000011.png 596 504
# a
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000370.png 807 579
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000191.png 362 362
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000221.png 397 506
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000252.png 485 347
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000075.png 298 347
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000378.png 280 273
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000422.png 721 651
# a
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000037.png 541 492
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000384.png 581 541
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000209.png 287 275
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000411.png 1465 1407
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000218.png 397 506
# a
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000282.png 590 740
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000036.png 240 345
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000457.png 303 205
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000144.png 553 624
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000233.png 271 186
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000141.png 553 624
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000223.png 596 504
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000390.png 525 379
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000200.png 519 463
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000041.png 541 492
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000373.png 280 273
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000449.png 502 761
# a
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000009.png 596 504
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000067.png 438 722
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000344.png 429 463
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000265.png 372 406
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000326.png 504 455
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000174.png 690 695
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000219.png 397 506
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000129.png 561 515
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000253.png 263 246
# a
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000100.png 863 851
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000012.png 596 504
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000010.png 596 504
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000135.png 1019 1188
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000360.png 358 299
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000190.png 362 362
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000366.png 642 749
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000057.png 442 442
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000015.png 180 196
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000312.png 504 529
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000078.png 298 347
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000382.png 581 541
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000217.png 397 506
# a
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000040.png 541 492
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000155.png 302 252
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000062.png 596 662
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000123.png 310 404
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000255.png 263 246
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000064.png 596 662
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000068.png 438 722
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000207.png 287 275
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000134.png 1019 1188
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000014.png 180 196
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000021.png 590 740
# a
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000151.png 302 252
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000420.png 1810 1775
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000079.png 421 590
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000220.png 397 506
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000362.png 642 749
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000225.png 596 504
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000029.png 723 595
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000309.png 504 529
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000112.png 1054 1730
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000085.png 665 585
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000452.png 240 345
# a
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000438.png 280 308
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000450.png 502 761
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000416.png 1810 1775
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000066.png 596 662
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000281.png 590 740
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000357.png 358 299
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000095.png 504 529
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000146.png 385 361
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000023.png 590 740
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000278.png 590 740
# a
# a
# a
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000074.png 298 347
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000188.png 362 362
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000006.png 637 516
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000013.png 180 196
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000148.png 385 361
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000345.png 429 463
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000163.png 487 285
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000213.png 242 312
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000395.png 606 421
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000339.png 637 537
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000393.png 606 421
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000083.png 421 590
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000106.png 648 959
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000246.png 378 424
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000130.png 561 515
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000436.png 280 308
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000259.png 233 334
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000098.png 863 851
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000446.png 502 761
# a
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000182.png 337 278
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000091.png 504 529
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000143.png 553 624
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000047.png 595 464
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000045.png 595 464
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000377.png 280 273
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000184.png 337 278
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000363.png 642 749
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000394.png 606 421
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000270.png 372 406
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000431.png 277 383
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000272.png 215 421
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000307.png 504 529
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000117.png 372 369
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000456.png 240 345
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000285.png 497 511
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000280.png 590 740
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000204.png 519 463
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000432.png 277 383
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000171.png 690 695
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000088.png 665 585
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000404.png 774 704
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000160.png 315 281
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000448.png 502 761
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000405.png 774 704
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000386.png 525 379
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000284.png 497 511
# a
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000118.png 372 369
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000175.png 467 574
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000125.png 310 404
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000257.png 263 246
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000367.png 807 579
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000454.png 240 345
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000149.png 385 361
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000350.png 877 673
# a
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000054.png 334 371
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000258.png 263 246
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000090.png 665 585
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000358.png 358 299
# a
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000073.png 298 347
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000266.png 372 406
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000328.png 504 455
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000093.png 504 529
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000028.png 723 595
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000119.png 372 369
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000248.png 485 347
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000260.png 233 334
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000447.png 502 761
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000114.png 1054 1730
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000121.png 310 404
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000453.png 240 345
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000162.png 315 281
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000206.png 287 275
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000286.png 497 511
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000018.png 180 196
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000031.png 240 345
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000229.png 271 186
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000385.png 525 379
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000397.png 674 523
# a
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000158.png 315 281
# a
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000131.png 561 515
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000374.png 280 273
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000237.png 396 541
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000177.png 467 574
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000227.png 596 504
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000168.png 487 285
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000019.png 590 740
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000275.png 215 421
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000325.png 504 455
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000105.png 648 959
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000176.png 467 574
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000052.png 334 371
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000336.png 372 541
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000069.png 438 722
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000361.png 642 749
# a
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000107.png 648 959
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000166.png 487 285
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000228.png 596 504
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000099.png 863 851
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000035.png 240 345
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000210.png 287 275
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000327.png 504 455
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000461.png 303 205
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000111.png 1054 1730
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000024.png 590 740
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000147.png 385 361
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000115.png 372 369
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000038.png 541 492
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000167.png 487 285
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000435.png 280 308
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000108.png 648 959
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000183.png 337 278
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000331.png 372 541
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000110.png 1054 1730
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000329.png 504 455
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000242.png 378 424
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000196.png 547 599
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000195.png 547 599
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000287.png 497 511
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000138.png 1019 1188
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000349.png 877 673
# a
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000263.png 233 334
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000194.png 547 599
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000140.png 553 624
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000406.png 774 704
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000355.png 358 299
# a
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000462.png 303 205
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000347.png 429 463
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000002.png 637 516
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000459.png 303 205
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000230.png 271 186
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000238.png 396 541
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000201.png 519 463
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000335.png 372 541
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000256.png 263 246
# a
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000408.png 774 704
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000398.png 674 523
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000379.png 581 541
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000243.png 378 424
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000261.png 233 334
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000126.png 310 404
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000016.png 180 196
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000333.png 372 541
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000127.png 561 515
# a
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000376.png 280 273
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000007.png 596 504
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000124.png 310 404
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000412.png 1465 1407
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000058.png 442 442
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000426.png 721 651
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000430.png 277 383
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000164.png 487 285
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000170.png 690 695
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000101.png 863 851
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000173.png 690 695
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000365.png 642 749
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000003.png 637 516
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000187.png 362 362
# a
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000215.png 242 312
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000050.png 334 371
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000226.png 596 504
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000161.png 315 281
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000277.png 590 740
# a
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000137.png 1019 1188
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000402.png 674 523
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000032.png 240 345
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000203.png 519 463
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000279.png 590 740
# a
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000232.png 271 186
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000455.png 240 345
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000414.png 1465 1407
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000231.png 271 186
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000236.png 396 541
# a
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000330.png 504 455
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000269.png 372 406
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000056.png 442 442
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000342.png 637 537
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000113.png 1054 1730
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000208.png 287 275
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000276.png 215 421
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000081.png 421 590
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000020.png 590 740
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000388.png 525 379
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000451.png 240 345
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000063.png 596 662
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000337.png 637 537
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000025.png 723 595
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000391.png 606 421
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000407.png 774 704
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000338.png 637 537
# a
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000288.png 497 511
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000425.png 721 651
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000387.png 525 379
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000051.png 334 371
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000380.png 581 541
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000159.png 315 281
# a
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000169.png 690 695
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000410.png 1465 1407
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000419.png 1810 1775
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000026.png 723 595
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000445.png 502 761
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000120.png 372 369
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000251.png 485 347
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000153.png 302 252
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000239.png 396 541
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000030.png 723 595
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000427.png 277 383
# a
# a
# a
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000371.png 807 579
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000418.png 1810 1775
# a
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000065.png 596 662
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000351.png 877 673
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000249.png 485 347
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000048.png 595 464
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000156.png 302 252
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000334.png 372 541
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000039.png 541 492
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000172.png 690 695
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000244.png 378 424
# a
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000262.png 233 334
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000264.png 233 334
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000369.png 807 579
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000214.png 242 312
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000001.png 637 516
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000070.png 438 722
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000271.png 215 421
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000008.png 596 504
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000283.png 497 511
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000103.png 648 959
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000139.png 553 624
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000046.png 595 464
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000060.png 442 442
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000340.png 637 537
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000181.png 337 278
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000399.png 674 523
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000359.png 358 299
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000241.png 378 424
# a
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000368.png 807 579
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000096.png 504 529
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000343.png 429 463
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000311.png 504 529
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000049.png 334 371
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000310.png 504 529
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000356.png 358 299
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000145.png 385 361
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000224.png 596 504
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000375.png 280 273
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000027.png 723 595
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000017.png 180 196
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000433.png 280 308
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000157.png 315 281
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000136.png 1019 1188
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000267.png 372 406
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000240.png 396 541
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000080.png 421 590
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000415.png 1810 1775
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000071.png 438 722
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000150.png 385 361
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000372.png 807 579
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000354.png 877 673
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000128.png 561 515
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000308.png 504 529
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000392.png 606 421
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000133.png 1019 1188
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000043.png 595 464
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000389.png 525 379
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000198.png 547 599
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000417.png 1810 1775
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000434.png 280 308
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000424.png 721 651
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000193.png 547 599
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000086.png 665 585
# a
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000346.png 429 463
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000400.png 674 523
# a
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000460.png 303 205
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000245.png 378 424
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000205.png 287 275
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000222.png 397 506
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000348.png 429 463
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000059.png 442 442
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000189.png 362 362
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000116.png 372 369
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000109.png 1054 1730
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000234.png 271 186
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000442.jpg 596 504
# a
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000297.jpg 380 352
# a
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000289.jpg 637 537
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000324.jpg 539 630
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000292.jpg 637 537
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000320.jpg 539 630
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000298.jpg 380 352
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000441.jpg 596 504
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000440.jpg 596 504
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000323.jpg 539 630
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000301.jpg 474 464
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000295.jpg 380 352
# a
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000306.jpg 474 464
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000443.jpg 596 504
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000296.jpg 380 352
# a
# a
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000439.jpg 596 504
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000319.jpg 539 630
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000303.jpg 474 464
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000321.jpg 539 630
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000291.jpg 637 537
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000317.jpg 149 109
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000318.jpg 149 109
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000304.jpg 474 464
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000444.jpg 596 504
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000314.jpg 149 109
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000322.jpg 539 630
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000299.jpg 380 352
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000315.jpg 149 109
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000316.jpg 149 109
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000294.jpg 637 537
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000313.jpg 149 109
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000305.jpg 474 464
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000300.jpg 380 352
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000302.jpg 474 464
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000290.jpg 637 537
# a
# a
# /home/nacho/TFI-Cazcarra/data/tiles/image_slices/000293.jpg 637 537
# a
# a
#                                           image_path  xmin  ymin  xmax  ymax  \
# 0  /home/nacho/TFI-Cazcarra/data/tiles/image_slic...   277   318   333   366
# 1  /home/nacho/TFI-Cazcarra/data/tiles/image_slic...   376   466   433   519
# 2  /home/nacho/TFI-Cazcarra/data/tiles/image_slic...   538   270   590   321
# 3  /home/nacho/TFI-Cazcarra/data/tiles/image_slic...   609   366   661   421
# 4  /home/nacho/TFI-Cazcarra/data/tiles/image_slic...   717   738   769   801
#
#              label
# 0  muchos_opcional
# 1  muchos_opcional
# 2  muchos_opcional
# 3  muchos_opcional
# 4  muchos_opcional

# %%
get_val_count(csv)
# Out:
# uno_obligatorio       1006
# muchos_obligatorio     823
# uno_opcional           325
# muchos_opcional        314
# Name: label, dtype: int64

# %%
mapper = pd.read_csv("../data/tiles/mapper.csv")
mapper.columns = ["image_name","tile1","tile2","tile3","tile4","tile5","tile6"]

for c in mapper.columns[1:]:
    mapper[c] = mapper[c].apply(lambda x: str(x).zfill(6))

# %%
mapper.head()
# Out:
#            image_name   tile1   tile2   tile3   tile4   tile5   tile6
# 0   ERDiagramsMySQL-1  000001  000002  000003  000004  000005  000006
# 1  ERDiagramsMySQL-10  000007  000008  000009  000010  000011  000012
# 2  ERDiagramsMySQL-11  000013  000014  000015  000016  000017  000018
# 3  ERDiagramsMySQL-12  000019  000020  000021  000022  000023  000024
# 4  ERDiagramsMySQL-13  000025  000026  000027  000028  000029  000030

# %%
train_original = pd.read_csv("../data/csv/train_diagramas_2023.csv")
train_images = train_original.image_path.unique()
train_images = [img_path.split(os.sep)[-1].split(".")[0] for img_path in train_images]

# %%
train_sliced = csv[csv['image_path'].isin(train_images)]
test_sliced = csv[~csv['image_path'].isin(train_images)]

# %%
def get_original_image(slice_path, mapper=mapper):
    img_path = slice_path.split(os.sep)[-1]
    img_path = img_path.split(".")[0]
    mapper = mapper.set_index("image_name")
    mapper_t = mapper.T
    for c in mapper_t.columns:
        if img_path in mapper_t[c].values:
            return c
    return None

csv['original_img_path'] = csv['image_path'].apply(lambda x: get_original_image(x))
csv.head()
# Out:
#                                           image_path  xmin  ymin  xmax  ymax  \
# 0  /home/nacho/TFI-Cazcarra/data/tiles/image_slic...   277   318   333   366
# 1  /home/nacho/TFI-Cazcarra/data/tiles/image_slic...   376   466   433   519
# 2  /home/nacho/TFI-Cazcarra/data/tiles/image_slic...   538   270   590   321
# 3  /home/nacho/TFI-Cazcarra/data/tiles/image_slic...   609   366   661   421
# 4  /home/nacho/TFI-Cazcarra/data/tiles/image_slic...   717   738   769   801
#
#              label original_img_path
# 0  muchos_opcional         example35
# 1  muchos_opcional         example35
# 2  muchos_opcional         example35
# 3  muchos_opcional         example35
# 4  muchos_opcional         example35

# %%
train_sliced = csv[csv['original_img_path'].isin(train_images)]
test_sliced = csv[~csv['original_img_path'].isin(train_images)]

# %%
print(train_sliced.shape)
print(test_sliced.shape)
# Out:
# (1659, 7)
# (809, 7)

# %%
train_sliced.drop(columns=["original_img_path"]).to_csv(f"{PATH}/data/tiles/train_cardinalidades_2023.csv")
test_sliced.drop(columns=["original_img_path"]).to_csv(f"{PATH}/data/tiles/test_cardinalidades_2023.csv")

# %%
train_sliced.head(6)
# Out:
#                                           image_path  xmin  ymin  xmax  ymax  \
# 0  /home/nacho/TFI-Cazcarra/data/tiles/image_slic...   277   318   333   366
# 1  /home/nacho/TFI-Cazcarra/data/tiles/image_slic...   376   466   433   519
# 2  /home/nacho/TFI-Cazcarra/data/tiles/image_slic...   538   270   590   321
# 3  /home/nacho/TFI-Cazcarra/data/tiles/image_slic...   609   366   661   421
# 4  /home/nacho/TFI-Cazcarra/data/tiles/image_slic...   717   738   769   801
# 5  /home/nacho/TFI-Cazcarra/data/tiles/image_slic...   920   530   970   579
#
#              label original_img_path
# 0  muchos_opcional         example35
# 1  muchos_opcional         example35
# 2  muchos_opcional         example35
# 3  muchos_opcional         example35
# 4  muchos_opcional         example35
# 5  muchos_opcional         example35
